# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme()

# %%
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\Karthik Garimella\Desktop\Project\Dataset\2017+2018.csv')

# %%
df
# Out:
#     Div        Date        HomeTeam        AwayTeam  FTWG  FTLG  FTHG  FTAG  \
# 0     1  12-08-2017        Brighton        Man City     2     0     0     2
# 1     2  21-08-2017        Man City         Everton     1     1     1     1
# 2     3  26-08-2017     Bournemouth        Man City     2     1     1     2
# 3     4  09-09-2017        Man City       Liverpool     5     0     5     0
# 4     5  16-09-2017         Watford        Man City     6     0     0     6
# 5     6  23-09-2017        Man City  Crystal Palace     5     0     5     0
# 6     7  30-09-2017         Chelsea        Man City     1     0     0     1
# 7     8  14-10-2017        Man City           Stoke     7     2     7     2
# 8     9  21-10-2017        Man City         Burnley     3     0     3     0
# 9    10  28-10-2017       West Brom        Man City     3     2     2     3
# 10   11  05-11-2017        Man City         Arsenal     3     1     3     1
# ...

# %%
df.describe()
# Out:
#              Div       FTWG       FTLG       FTHG       FTAG       HTHG  \
# count  38.000000  38.000000  38.000000  38.000000  38.000000  38.000000
# mean   19.500000   2.789474   0.710526   1.947368   1.552632   0.736842
# std    11.113055   1.596582   0.897682   1.888047   1.389096   0.794719
# min     1.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%    10.250000   2.000000   0.000000   0.000000   1.000000   0.000000
# 50%    19.500000   3.000000   1.000000   1.000000   1.000000   1.000000
# 75%    28.750000   3.750000   1.000000   3.000000   2.000000   1.000000
# max    38.000000   7.000000   4.000000   7.000000   6.000000   3.000000
#
#             HTAG         HS         AS        HST  ...         HC         AC  \
# count  38.000000  38.000000  38.000000  38.000000  ...  38.000000  38.000000
# mean    0.763158  12.605263  11.131579   5.210526  ...   5.105263   5.078947
# std     0.942516   6.847921   6.588980   3.699218  ...   3.423208   3.664155
# ...

# %%
plt.plot(df['FTWG'],df['xG'])
plt.xlabel('Goals Scored')
plt.ylabel('xG of Manchester City')
plt.title('Goal Scoring Pattern')
# Out:
# Text(0.5, 1.0, 'Goal Scoring Pattern')

# %%
plt.plot(df['xG'],df['FTWG'])
plt.xlabel('xG')
plt.ylabel('FTWG')
plt.title('Goal Scoring Pattern based on xG')
# Out:
# Text(0.5, 1.0, 'Goal Scoring Pattern based on xG')

# %%
plt.plot(df['FTLG'],df['xGA'])
plt.xlabel('Goals Scored')
plt.ylabel('xG of Manchester City')
plt.title('Goal Scoring Pattern')
# Out:
# Text(0.5, 1.0, 'Goal Scoring Pattern')

# %%
df['FTWG'].plot(kind='hist');

# %%
df['FTWG'].plot.area()

# %%
df['xG'].plot(kind='hist');

# %%
df.plot(kind='scatter',x='FTWG',y='xG',s=100,c='xG',cmap='coolwarm')

# %%
df.plot(kind='scatter',x='FTLG',y='xGA',s=100,c='xGA',cmap='coolwarm')

# %%
sns.displot(df['FTWG'],kde=True,bins=15)

# %%
sns.displot(df['FTLG'],kde=True,bins=15)

# %%
sns.displot(df['xG'],kde=True)

# %%
sns.displot(df['xGA'],kde=True,bins=15)

# %%
sns.displot(df['PPDA'],kde=True,bins=15)

# %%
sns.jointplot(x='FTWG',y='xG',data=df,s=100)

# %%
sns.jointplot(x='xG',y='xGA',data=df,kind='reg',scatter_kws={'s':100})

# %%
sns.jointplot(x='xG',y='PPDA',data=df,s=100)

# %%
sns.jointplot(x='FTWG',y='FTLG',data=df,s=100)

# %%
sns.jointplot(x='FTWG',y='xG',data=df,kind='reg',scatter_kws={'s':100})

# %%
sns.jointplot(x='FTLG',y='xGA',data=df,kind='reg',scatter_kws={'s':100})

# %%
sns.jointplot(x='xG',y='PPDA',data=df,kind='reg',scatter_kws={'s':100})

# %%
sns.displot(data=df, kind="ecdf", x="FTWG", rug=True)

# %%
sns.relplot(data=df,x='FTWG',y='xG',hue="FTWG",s=300)

# %%
sns.relplot(data=df,x='PPDA',y='FTWG',hue="FTWG",s=300)

# %%
sns.relplot(data=df,x='FTWG',y='xG',hue="xG",col='WDL',s=500)

# %%
sns.relplot(
    data=df, kind="line",
    x="FTWG", y="Date")

# %%
sns.relplot(
    data=df, kind="line",
    x="Date",y="FTWG" 
)

# %%
sns.relplot(
    data=df, kind="line",
    x="FTWG", y="xG"
)

# %%
sns.lmplot(data=df, x="FTWG", y="xG", col="WDL", hue="FTWG",scatter_kws={'s':100})

# %%
sns.lmplot(data=df, x="FTWG", y="xG", hue="FTWG",scatter_kws={'s':100},markers=['o','v','X','p','*','h','8','D'])

# %%
sns.relplot(data=df,kind='line')

# %%
sns.relplot(data=df,x='FTWG',y='xG',hue="FTWG",s = 200)

# %%
sns.scatterplot(data=df,x='xG',y='FTWG',hue="xG",style='WDL',s =100)

# %%
sns.scatterplot(data=df,x='PPDA',y='aPPDA',hue="xG",style='WDL',s =100)

# %%
sns.scatterplot(data=df,x='xGA',y='FTWG',hue="xGA",style='WDL',s =100)

# %%
sns.lmplot(data=df, x="FTWG", y="xG", col="WDL", hue="WDL",markers=['o','v','x'],scatter_kws={'s':100})

# %%
sns.lmplot(data=df, x="xGA", y="xG", col="WDL", hue="WDL",markers=['o','v','x'],scatter_kws={'s':100})

# %%
sns.lmplot(data=df, x="xG", y="xGA", col="WDL", hue="WDL",markers=['o','v','x'],scatter_kws={'s':100})

# %%
sns.lmplot(data=df, x="FTLG", y="xGA", col="WDL", hue="WDL",markers=['o','v','x'],scatter_kws={'s':100})

# %%
sns.lmplot(data=df, x="FTWG", y="FTLG", col="WDL", hue="WDL",markers=['o','v','x'],scatter_kws={'s':100})

# %%
sns.lmplot(data=df, x="PPDA", y="aPPDA", col="WDL", hue="WDL",markers=['o','v','x'],scatter_kws={'s':100})

# %%
corr=df.corr()

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')

# %%
df.pivot_table(index='xG',values='FTWG')
# Out:
#           FTWG
# xG
# 0.72  3.000000
# 0.77  1.000000
# 0.79  0.000000
# 0.95  1.000000
# 1.10  0.000000
# 1.14  1.000000
# 1.23  1.000000
# 1.56  4.000000
# 1.65  2.333333
# 1.77  2.000000
# 1.87  2.000000
# 1.91  3.000000
# 1.93  2.000000
# 2.03  2.000000
# 2.15  3.000000
# 2.25  1.000000
# 2.29  4.000000
# 2.40  2.000000
# 2.46  2.000000
# 2.55  3.000000
# 2.59  5.000000
# 2.66  2.000000
# 2.69  3.000000
# 2.77  3.000000
# 3.15  5.000000
# 3.43  3.500000
# 3.57  4.000000
# 3.62  3.000000
# 3.72  3.000000
# 3.99  6.000000
# 4.15  4.000000
# 4.45  7.000000
# 5.73  5.000000

# %%
heatmap=df.pivot_table(index='xG',values='FTWG')

# %%
sns.heatmap(heatmap,cmap='coolwarm')

# %%
sns.heatmap(heatmap,cmap='coolwarm',linewidths=1,linecolor='green')

# %%
sns.boxenplot(x=df.FTHG,y=df.xG)

# %%
date=df['Date']
ft_goals=df['FTWG']
plt.plot_date(date, ft_goals, linestyle='solid')

# %%
xG_w=df['xG']
date1=df['Date']
plt.plot_date(date1,xG_w, linestyle='solid')

# %%
date=df['Date']
ft_goals=df['FTLG']
plt.plot_date(date, ft_goals, linestyle='solid')

# %%
xG_w=df['xGA']
date1=df['Date']
plt.plot_date(date1,xG_w, linestyle='solid')

# %%
xG_w=df['WDL']
date1=df['Date']
plt.plot_date(date1,xG_w, linestyle='solid')

# %%
df0=df.pivot_table(index='FTWG',columns='Date',values='xG')
df0
# Out:
# Date  01-03-2018  02-01-2018  03-02-2018  03-12-2017  04-03-2018  05-11-2017  \
# FTWG
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN        2.25         NaN        0.95         NaN
# 2            NaN         NaN         NaN        2.46         NaN         NaN
# 3           1.93        2.77         NaN         NaN         NaN        2.15
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# 5            NaN         NaN         NaN         NaN         NaN         NaN
# 6            NaN         NaN         NaN         NaN         NaN         NaN
# 7            NaN         NaN         NaN         NaN         NaN         NaN
#
# Date  06-05-2018  07-04-2018  09-05-2018  09-09-2017  ...  26-08-2017  \
# FTWG                                                  ...
# 0           0.79         NaN         NaN         NaN  ...         NaN
# ...

# %%
sns.heatmap(df0,cmap='coolwarm')

# %%
df0=df.pivot_table(index='FTLG',columns='Date',values='xGA')
df0
# Out:
# Date  01-03-2018  02-01-2018  03-02-2018  03-12-2017  04-03-2018  05-11-2017  \
# FTLG
# 0            1.3         NaN         NaN         NaN        0.12         NaN
# 1            NaN        0.97         0.8        0.47         NaN        0.34
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
#
# Date  06-05-2018  07-04-2018  09-05-2018  09-09-2017  ...  26-08-2017  \
# FTLG                                                  ...
# 0           0.55         NaN         NaN        0.67  ...         NaN
# 1            NaN         NaN        1.01         NaN  ...        0.42
# 2            NaN         NaN         NaN         NaN  ...         NaN
# 3            NaN        1.22         NaN         NaN  ...         NaN
# 4            NaN         NaN         NaN         NaN  ...         NaN
#
# ...

# %%
sns.heatmap(df0,cmap='coolwarm')

# %%
xG=df['xG']
date=df['Date']
plt.bar(date, xG, color ='blue', 
        width = 1)
plt.xlabel("xG Time Analysis")
plt.ylabel("Date")
plt.title("xG")
# Out:
# Text(0.5, 1.0, 'xG')

# %%
Goals = df['FTWG']
date=df['Date']
plt.bar(date, Goals, color ='blue', 
        width = 1)
plt.xlabel("Goals Scored Time Analysis")
plt.ylabel("Date")
plt.title("Goals Scored")
# Out:
# Text(0.5, 1.0, 'Goals Scored')

# %%
Goals = df['FTLG']
date=df['Date']
plt.bar(date, Goals, color ='red', 
        width = 1)
plt.xlabel("Goals Scored Time Analysis")
plt.ylabel("Date")
plt.title("Goals Conceded")
# Out:
# Text(0.5, 1.0, 'Goals Conceded')

# %%
Goals = df['xGA']
date=df['Date']
plt.bar(date, Goals, color ='red', 
        width = 1)
plt.xlabel("Goals Scored Time Analysis")
plt.ylabel("Date")
plt.title("Goals Conceded xGA")
# Out:
# Text(0.5, 1.0, 'Goals Conceded xGA')

# %%
xG=df['xGA']
Goals = df['FTLG']
date=df['Date']
plt.bar(date, Goals, color ='blue', 
        width = 1)
plt.xlabel("Goals Scored Time Analysis")
plt.ylabel("Date")
plt.title("Goals Conceded")
# Out:
# Text(0.5, 1.0, 'Goals Conceded')

# %%
xG_l=df['WDL']
date1=df['Date']
plt.plot_date(date1,xG_l, linestyle='solid')

# %%
df11=df.pivot_table(index='Date',columns='FTWG',values='xG')
df11
# Out:
# FTWG           0     1     2     3     4     5     6     7
# Date
# 01-03-2018   NaN   NaN   NaN  1.93   NaN   NaN   NaN   NaN
# 02-01-2018   NaN   NaN   NaN  2.77   NaN   NaN   NaN   NaN
# 03-02-2018   NaN  2.25   NaN   NaN   NaN   NaN   NaN   NaN
# 03-12-2017   NaN   NaN  2.46   NaN   NaN   NaN   NaN   NaN
# 04-03-2018   NaN  0.95   NaN   NaN   NaN   NaN   NaN   NaN
# 05-11-2017   NaN   NaN   NaN  2.15   NaN   NaN   NaN   NaN
# 06-05-2018  0.79   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 07-04-2018   NaN   NaN  3.43   NaN   NaN   NaN   NaN   NaN
# 09-05-2018   NaN   NaN   NaN  1.65   NaN   NaN   NaN   NaN
# 09-09-2017   NaN   NaN   NaN   NaN   NaN  3.15   NaN   NaN
# 10-02-2018   NaN   NaN   NaN   NaN   NaN  2.59   NaN   NaN
# 10-12-2017   NaN   NaN  2.03   NaN   NaN   NaN   NaN   NaN
# 12-03-2018   NaN   NaN  1.65   NaN   NaN   NaN   NaN   NaN
# 12-08-2017   NaN   NaN  1.87   NaN   NaN   NaN   NaN   NaN
# 13-05-2018   NaN  0.77   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
sns.heatmap(df11,cmap=('coolwarm'))

# %%
df01=df.pivot_table(index='Date',columns='FTLG',values='xGA')
df01
# Out:
# FTLG           0      1     2     3     4
# Date
# 01-03-2018  1.30    NaN   NaN   NaN   NaN
# 02-01-2018   NaN  0.970   NaN   NaN   NaN
# 03-02-2018   NaN  0.800   NaN   NaN   NaN
# 03-12-2017   NaN  0.470   NaN   NaN   NaN
# 04-03-2018  0.12    NaN   NaN   NaN   NaN
# 05-11-2017   NaN  0.340   NaN   NaN   NaN
# 06-05-2018  0.55    NaN   NaN   NaN   NaN
# 07-04-2018   NaN    NaN   NaN  1.22   NaN
# 09-05-2018   NaN  1.010   NaN   NaN   NaN
# 09-09-2017  0.67    NaN   NaN   NaN   NaN
# 10-02-2018   NaN  0.110   NaN   NaN   NaN
# 10-12-2017   NaN  1.440   NaN   NaN   NaN
# 12-03-2018  0.16    NaN   NaN   NaN   NaN
# 12-08-2017  0.28    NaN   NaN   NaN   NaN
# 13-05-2018  0.51    NaN   NaN   NaN   NaN
# 13-12-2017  0.59    NaN   NaN   NaN   NaN
# 14-01-2018   NaN    NaN   NaN   NaN  1.02
# 14-04-2018   NaN  0.460   NaN   NaN   NaN
# 14-10-2017   NaN    NaN  0.68   NaN   NaN
# 16-09-2017  0.80    NaN   NaN   NaN   NaN
# 16-12-2017   NaN  0.180   NaN   NaN   NaN
# ...

# %%
sns.heatmap(df01,cmap='coolwarm')

# %%
df011=df.pivot_table(index='FTLG',columns='Date',values='xGA')
df011
# Out:
# Date  01-03-2018  02-01-2018  03-02-2018  03-12-2017  04-03-2018  05-11-2017  \
# FTLG
# 0            1.3         NaN         NaN         NaN        0.12         NaN
# 1            NaN        0.97         0.8        0.47         NaN        0.34
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
#
# Date  06-05-2018  07-04-2018  09-05-2018  09-09-2017  ...  26-08-2017  \
# FTLG                                                  ...
# 0           0.55         NaN         NaN        0.67  ...         NaN
# 1            NaN         NaN        1.01         NaN  ...        0.42
# 2            NaN         NaN         NaN         NaN  ...         NaN
# 3            NaN        1.22         NaN         NaN  ...         NaN
# 4            NaN         NaN         NaN         NaN  ...         NaN
#
# ...

# %%
sns.heatmap(df011,cmap='coolwarm')

# %%
df_xG=df.xG
df_xGA=df.xGA
df_xG_Diff=df_xG-df_xGA

print((df_xG_Diff).to_string(index=False),"\n\n",(df.WDL).to_string(index=False))
# Out:
#  1.590
#  0.540
#  1.350
#  2.480
#  3.190
#  5.120
#  0.320
#  3.770
#  3.570
#  1.650
#  1.810
#  2.300
#  2.120
#  1.479
#  1.990
#  0.590
#  2.980
#  3.970
#  1.230
#  1.760
# -0.620
#  1.800
# -0.300
#  1.560
#  2.570
#  1.450
#  2.480
#  0.630
#  0.830
#  1.490
#  1.050
#  2.210
#  3.160
#  3.130
#  2.060
#  0.240
#  0.640
#  0.260
#
#   W
#  D
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  D
#  W
#  L
#  W
#  W
#  D
#  W
#  W
#  W
#  W
#  W
#  L
#  W
#  W
#  W
#  D
#  W
#  W

# %%
pos_count=0
neg_count =0
null_count=0
for i in df_xG_Diff:
    if i > 0: 
        pos_count += 1
    elif i < 0: 
        neg_count += 1
    else:
        null_count+=1
print("Positive xG in 38 matches: ",pos_count)
print("Negative xG in 38 matches: ",neg_count)
print("Null Difference in xG in 38 matches: ",null_count)
# Out:
# Positive xG in 38 matches:  36
# Negative xG in 38 matches:  2
# Null Difference in xG in 38 matches:  0

# %%
df_FTWG=df.FTWG
df_FTLG=df.FTLG
df_GD=df_FTWG-df_FTLG
print((df_GD).to_string(index=False),"\n\n\n",df.WDL)
# Out:
#  2
#  0
#  1
#  5
#  6
#  5
#  1
#  5
#  3
#  1
#  2
#  2
#  1
#  1
#  1
#  1
#  4
#  3
#  4
#  1
#  0
#  2
# -1
#  2
#  3
#  0
#  4
#  3
#  1
#  2
#  2
# -1
#  2
#  5
#  3
#  0
#  2
#  1
#
#
#  0     W
# 1     D
# 2     W
# 3     W
# 4     W
# 5     W
# 6     W
# 7     W
# 8     W
# 9     W
# 10    W
# 11    W
# 12    W
# 13    W
# 14    W
# 15    W
# 16    W
# 17    W
# 18    W
# 19    W
# 20    D
# 21    W
# 22    L
# 23    W
# 24    W
# 25    D
# 26    W
# 27    W
# 28    W
# 29    W
# 30    W
# 31    L
# 32    W
# 33    W
# 34    W
# 35    D
# 36    W
# 37    W
# Name: WDL, dtype: object

# %%
pos_count=0
neg_count =0
null_count=0
for i in df_GD:
    if i > 0: 
        pos_count += 1
    elif i < 0: 
        neg_count += 1
    else:
        null_count+=1
print("Positive GD in 38 matches i.e. Wins: ",pos_count)
print("Negative GD in 38 matches i.e. Loss: ",neg_count)
print("Null Difference in GD in 38 matches i.e. Draws: ",null_count)
# Out:
# Positive GD in 38 matches i.e. Wins:  32
# Negative GD in 38 matches i.e. Loss:  2
# Null Difference in GD in 38 matches i.e. Draws:  4

# %%
df_PPDA=df.PPDA
df_aPPDA=df.aPPDA
df_PPDA_Diff=df_PPDA-df_aPPDA
print((df_PPDA_Diff).to_string(index=False),df.WDL)
# Out:
# -61.89
# -10.00
# -10.91
# -39.29
# -21.37
# -21.91
# -28.83
# -68.04
# -15.25
# -17.42
#  -3.49
# -21.18
# -21.46
# -13.94
# -24.62
#  -9.33
# -23.33
#   0.78
# -34.31
# -22.72
# -18.50
# -20.06
#  -7.07
# -12.63
# -23.18
# -11.21
# -22.50
# -10.38
# -74.14
# -39.83
# -21.38
#  -5.55
#  -1.68
# -35.46
# -25.57
# -19.82
# -41.80
#  -7.45 0     W
# 1     D
# 2     W
# 3     W
# 4     W
# 5     W
# 6     W
# 7     W
# 8     W
# 9     W
# 10    W
# 11    W
# 12    W
# 13    W
# 14    W
# 15    W
# 16    W
# 17    W
# 18    W
# 19    W
# 20    D
# 21    W
# 22    L
# 23    W
# 24    W
# 25    D
# 26    W
# 27    W
# 28    W
# 29    W
# 30    W
# 31    L
# 32    W
# 33    W
# 34    W
# 35    D
# 36    W
# 37    W
# Name: WDL, dtype: object

# %%
pos_count=0
neg_count =0
null_count=0
for i in df_PPDA_Diff:
    if i > 0: 
        pos_count += 1
    elif i < 0: 
        neg_count += 1
    else:
        null_count+=1
print("Positive PPDA in 38 matches : ",pos_count)
print("Negative PPDA in 38 matches : ",neg_count)
print("Null Difference in PPDA in 38 matches : ",null_count)
# Out:
# Positive PPDA in 38 matches :  1
# Negative PPDA in 38 matches :  37
# Null Difference in PPDA in 38 matches :  0

# %%
df.WDL
# Out:
# 0     W
# 1     D
# 2     W
# 3     W
# 4     W
# 5     W
# 6     W
# 7     W
# 8     W
# 9     W
# 10    W
# 11    W
# 12    W
# 13    W
# 14    W
# 15    W
# 16    W
# 17    W
# 18    W
# 19    W
# 20    D
# 21    W
# 22    L
# 23    W
# 24    W
# 25    D
# 26    W
# 27    W
# 28    W
# 29    W
# 30    W
# 31    L
# 32    W
# 33    W
# 34    W
# 35    D
# 36    W
# 37    W
# Name: WDL, dtype: object

# %%
df.plot.line(x='Date',y='FTWG',lw=3,color='r',figsize=(12,3))

# %%
sns.lineplot(data=df.FTWG, color="r",lw=5)
ax2 = plt.twinx()
sns.lineplot(data=df.xG, color="b", ax=ax2,lw=1)

# %%
sns.lineplot(data=df.FTLG, color="r",lw=5)
ax2 = plt.twinx()
sns.lineplot(data=df.xGA, color="b", ax=ax2,lw=1)

# %%
labels=np.array(['FTWG','FTLG','xG','xGA'])
stats=df.loc[15,labels].values
angles=np.linspace(0, 2*np.pi, len(labels), endpoint=False)
# close the plot
stats=np.concatenate((stats,[stats[0]]))
angles=np.concatenate((angles,[angles[0]]))

# %%
fig=plt.figure()
ax = fig.add_subplot(111, polar=True)  
ax.plot(angles, stats, 'o-', linewidth=2)  
ax.fill(angles, stats, alpha=0.25) 
ax.set_thetagrids(angles * 180/np.pi, labels) 
ax.set_title([df.loc[15,"HomeTeam"]]) 
#ax.set_rlim(0,250)
ax.grid(True)

#For 36th Match of Leicester City

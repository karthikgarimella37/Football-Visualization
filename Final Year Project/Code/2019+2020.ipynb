# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme()

# %%
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\Karthik Garimella\Desktop\Project\Dataset\2019+2020.csv')

# %%
df
# Out:
#     Div        Date   Time          HomeTeam          AwayTeam  FTWG  FTLG  \
# 0     1  09-08-2019  20:00         Liverpool           Norwich     4     1
# 1     2  17-08-2019  15:00       Southampton         Liverpool     2     1
# 2     3  24-08-2019  17:30         Liverpool           Arsenal     3     1
# 3     4  31-08-2019  17:30           Burnley         Liverpool     3     0
# 4     5  14-09-2019  12:30         Liverpool         Newcastle     3     1
# 5     6  22-09-2019  16:30           Chelsea         Liverpool     2     1
# 6     7  28-09-2019  12:30  Sheffield United         Liverpool     1     0
# 7     8  05-10-2019  15:00         Liverpool         Leicester     2     1
# 8     9  20-10-2019  16:30        Man United         Liverpool     1     1
# 9    10  27-10-2019  16:30         Liverpool         Tottenham     2     1
# 10   11  02-11-2019  15:00       Aston Villa         Liverpool     2     1
# 11   12  10-11-2019  16:30         Liverpool          Man City     3     1
# 12   13  23-11-2019  15:00    Crystal Palace         Liverpool     2     1
# 13   14  30-11-2019  15:00         Liverpool          Brighton     2     1
# 14   15  04-12-2019  20:15         Liverpool           Everton     5     2
# 15   16  07-12-2019  15:00       Bournemouth         Liverpool     3     0
# 16   17  14-12-2019  12:30         Liverpool           Watford     2     0
# 17   18  26-12-2019  20:00         Leicester         Liverpool     4     0
# 18   19  29-12-2019  16:30         Liverpool            Wolves     1     0
# 19   20  02-01-2020  20:00         Liverpool  Sheffield United     2     0
# 20   21  11-01-2020  17:30         Tottenham         Liverpool     1     0
# 21   22  19-01-2020  16:30         Liverpool        Man United     2     0
# 22   23  23-01-2020  20:00            Wolves         Liverpool     2     1
# 23   24  29-01-2020  19:45          West Ham         Liverpool     2     0
# 24   25  01-02-2020  15:00         Liverpool       Southampton     4     0
# 25   26  15-02-2020  17:30           Norwich         Liverpool     1     0
# 26   27  24-02-2020  20:00         Liverpool          West Ham     3     2
# 27   28  29-02-2020  17:30           Watford         Liverpool     0     3
# 28   29  07-03-2020  12:30         Liverpool       Bournemouth     2     1
# 29   30  21-06-2020  19:00           Everton         Liverpool     0     0
# 30   31  24-06-2020  20:15         Liverpool    Crystal Palace     4     0
# 31   32  02-07-2020  20:15          Man City         Liverpool     0     4
# 32   33  05-07-2020  16:30         Liverpool       Aston Villa     2     0
# 33   34  08-07-2020  20:15          Brighton         Liverpool     3     1
# 34   35  11-07-2020  15:00         Liverpool           Burnley     1     1
# 35   36  15-07-2020  20:15           Arsenal         Liverpool     1     2
# 36   37  22-07-2020  20:15         Liverpool           Chelsea     5     3
# 37   38  26-07-2020  16:00         Newcastle         Liverpool     3     1
#
#     FTHG  FTAG FTR  ...  HC  AC HY AY HR  AR    xG   xGA   PPDA  aPPDA
# 0      4     1   H  ...  11   2  0  2  0   0  2.23  0.84   5.94  21.45
# 1      1     2   A  ...   5   9  2  1  0   0  1.52  2.14   9.43  12.00
# 2      3     1   H  ...   6   4  1  1  0   0  2.79  0.99   9.78  28.43
# 3      0     3   A  ...   6   4  0  0  0   0  1.20  0.62   6.21  16.26
# 4      3     1   H  ...  10   1  0  0  0   0  2.93  0.29   6.96  41.90
# 5      1     2   A  ...   6   4  3  3  0   0  1.03  1.23   7.91  11.63
# 6      0     1   A  ...   6   5  1  1  0   0  1.97  1.17  11.27  24.24
# 7      2     1   H  ...   4   6  1  4  0   0  3.75  0.10   7.78   9.25
# 8      1     1   D  ...   3   1  0  1  0   0  1.03  0.79   5.17  31.50
# 9      2     1   H  ...   8   3  3  3  0   0  2.19  1.35   5.07  32.30
# 10     1     2   A  ...   2  10  1  2  0   0  2.39  0.74  20.93   4.40
# 11     3     1   H  ...   4  13  0  2  0   0  1.33  1.48  20.46  12.05
# 12     1     2   A  ...   9   8  0  1  0   0  1.64  1.02  10.11  21.92
# 13     2     1   H  ...   4   5  0  0  1   0  1.37  0.87  14.92  15.06
# 14     5     2   H  ...   5   6  1  2  0   0  2.41  1.76   9.68   9.00
# 15     0     3   A  ...   1   3  0  1  0   0  3.04  0.15   9.35  43.92
# 16     2     0   H  ...   6   3  2  1  0   0  1.57  1.01   5.04  17.77
# 17     0     4   A  ...   2   8  1  1  0   0  3.77  0.12  11.43  20.47
# 18     1     0   H  ...   5   6  1  0  0   0  1.49  0.36   6.27  21.33
# 19     2     0   H  ...   8   4  0  0  0   0  3.05  0.63  14.58  32.68
# 20     0     1   A  ...   4   3  0  2  0   0  1.75  1.11  12.30  29.94
# 21     2     0   H  ...  11   5  1  3  0   0  2.01  1.42  11.00  15.00
# 22     1     2   A  ...   2   4  0  1  0   0  1.59  1.85  11.89  22.38
# 23     0     2   A  ...   3   7  2  0  0   0  2.60  0.88   7.48  38.36
# 24     4     0   H  ...   6  11  0  2  0   0  3.72  0.72   6.23  12.74
# 25     0     1   A  ...   2   7  1  2  0   0  2.07  0.38   8.15  45.43
# 26     3     2   H  ...  16   8  0  3  0   0  2.48  0.64   3.36  33.70
# 27     3     0   H  ...   3   5  0  0  0   0  0.21  0.21  11.55  33.10
# 28     2     1   H  ...   9   4  0  1  0   0  1.89  1.30   4.75  20.29
# 29     0     0   D  ...   1   6  2  2  0   0  0.66  0.62   3.97  18.47
# 30     4     0   H  ...   6   0  0  0  0   0  2.57  0.06   5.17  79.17
# 31     4     0   H  ...   3   3  2  2  0   0  0.82  2.65  15.50  31.18
# 32     2     0   H  ...   7   5  1  1  0   0  1.06  0.69   3.72  20.82
# 33     1     3   A  ...   6  10  1  4  0   0  2.62  2.36   8.65  20.92
# 34     1     1   D  ...  12   6  1  2  0   0  2.18  0.45   8.69  23.47
# 35     2     1   H  ...   2  13  3  1  0   0  2.22  1.32   4.79  17.00
# 36     5     3   H  ...   6   0  1  0  0   0  1.45  2.38  12.10  14.75
# 37     1     3   A  ...   2   4  1  0  0   0  0.57  0.34   6.00  19.17
#
# [38 rows x 31 columns]

# %%
df.describe()
# Out:
#              Div       FTWG       FTLG       FTHG       FTAG      HTHG  \
# count  38.000000  38.000000  38.000000  38.000000  38.000000  38.00000
# mean   19.500000   2.236842   0.868421   1.815789   1.289474   1.00000
# std    11.113055   1.261364   0.963413   1.467767   1.088214   1.13899
# min     1.000000   0.000000   0.000000   0.000000   0.000000   0.00000
# 25%    10.250000   1.250000   0.000000   1.000000   0.250000   0.00000
# 50%    19.500000   2.000000   1.000000   2.000000   1.000000   1.00000
# 75%    28.750000   3.000000   1.000000   3.000000   2.000000   1.75000
# max    38.000000   5.000000   4.000000   5.000000   4.000000   4.00000
#
#             HTAG         HS         AS        HST  ...         HC         AC  \
# count  38.000000  38.000000  38.000000  38.000000  ...  38.000000  38.000000
# mean    0.578947  12.763158  11.789474   4.736842  ...   5.578947   5.421053
# std     0.721544   6.201282   5.388466   2.863415  ...   3.382240   3.210048
# min     0.000000   3.000000   2.000000   0.000000  ...   1.000000   0.000000
# 25%     0.000000   7.500000   8.250000   2.000000  ...   3.000000   3.250000
# 50%     0.000000  13.500000  11.500000   5.000000  ...   5.500000   5.000000
# 75%     1.000000  16.000000  15.000000   7.000000  ...   6.750000   7.000000
# max     2.000000  25.000000  25.000000  13.000000  ...  16.000000  13.000000
#
#               HY         AY         HR    AR         xG        xGA       PPDA  \
# count  38.000000  38.000000  38.000000  38.0  38.000000  38.000000  38.000000
# mean    0.868421   1.368421   0.026316   0.0   1.978158   0.974737   9.041842
# std     0.934939   1.148937   0.162221   0.0   0.879846   0.670162   4.247888
# min     0.000000   0.000000   0.000000   0.0   0.210000   0.060000   3.360000
# 25%     0.000000   0.250000   0.000000   0.0   1.390000   0.492500   5.955000
# 50%     1.000000   1.000000   0.000000   0.0   1.990000   0.855000   8.400000
# 75%     1.000000   2.000000   0.000000   0.0   2.547500   1.315000  11.390000
# max     3.000000   4.000000   1.000000   0.0   3.770000   2.650000  20.930000
#
#            aPPDA
# count  38.000000
# mean   24.301316
# std    13.571615
# min     4.400000
# 25%    15.360000
# 50%    21.125000
# 75%    31.420000
# max    79.170000
#
# [8 rows x 23 columns]

# %%
plt.plot(df['FTWG'],df['xG'])
plt.xlabel('Goals Scored')
plt.ylabel('xG of Manchester City')
plt.title('Goal Scoring Pattern')
# Out:
# Text(0.5, 1.0, 'Goal Scoring Pattern')

# %%
plt.plot(df['xG'],df['FTWG'])
plt.xlabel('xG')
plt.ylabel('FTWG')
plt.title('Goal Scoring Pattern based on xG')
# Out:
# Text(0.5, 1.0, 'Goal Scoring Pattern based on xG')

# %%
plt.plot(df['FTLG'],df['xGA'])
plt.xlabel('Goals Scored')
plt.ylabel('xG of Manchester City')
plt.title('Goal Scoring Pattern')
# Out:
# Text(0.5, 1.0, 'Goal Scoring Pattern')

# %%
df['FTWG'].plot(kind='hist');

# %%
df['FTWG'].plot.area()

# %%
df['xG'].plot(kind='hist');

# %%
df.plot(kind='scatter',x='FTWG',y='xG',s=100,c='xG',cmap='coolwarm')

# %%
df.plot(kind='scatter',x='FTLG',y='xGA',s=100,c='xGA',cmap='coolwarm')

# %%
sns.displot(df['FTWG'],kde=True,bins=15)

# %%
sns.displot(df['FTLG'],kde=True,bins=15)

# %%
sns.displot(df['xG'],kde=True)

# %%
sns.displot(df['xGA'],kde=True,bins=15)

# %%
sns.displot(df['PPDA'],kde=True,bins=15)

# %%
sns.jointplot(x='FTWG',y='xG',data=df,s=100)

# %%
sns.jointplot(x='xG',y='xGA',data=df,kind='reg',scatter_kws={'s':100})

# %%
sns.jointplot(x='xG',y='PPDA',data=df,s=100)

# %%
sns.jointplot(x='FTWG',y='xG',data=df,kind='reg',scatter_kws={'s':100})

# %%
sns.jointplot(x='FTLG',y='xGA',data=df,kind='reg',scatter_kws={'s':100})

# %%
sns.jointplot(x='xG',y='PPDA',data=df,kind='reg',scatter_kws={'s':100})

# %%
sns.displot(data=df, kind="ecdf", x="FTWG", rug=True)

# %%
sns.relplot(data=df,x='FTWG',y='xG',hue="FTWG",s=300)

# %%
sns.relplot(data=df,x='PPDA',y='FTWG',hue="FTWG",s=300)

# %%
sns.relplot(data=df,x='FTWG',y='xG',hue="xG",col='WDL',s=500)

# %%
sns.relplot(
    data=df, kind="line",
    x="FTWG", y="Date")

# %%
sns.relplot(
    data=df, kind="line",
    x="Date",y="FTWG" 
)

# %%
sns.relplot(
    data=df, kind="line",
    x="FTWG", y="xG"
)

# %%
sns.relplot(
    data=df, kind="line",
    x="FTLG", y="xGA"
)

# %%
sns.relplot(
    data=df, kind="scatter",
    x="FTLG", y="xGA"
)

# %%
sns.lmplot(data=df, x="FTWG", y="xG", col="WDL", hue="FTWG",scatter_kws={'s':100})

# %%
sns.lmplot(data=df, x="FTWG", y="FTLG", col="WDL", hue="FTWG",scatter_kws={'s':100})

# %%
sns.lmplot(data=df, x="xG", y="xGA", col="WDL", hue="FTWG",scatter_kws={'s':200})

# %%
sns.lmplot(data=df, x="FTWG", y="xG", hue="FTWG",scatter_kws={'s':100},markers=['o','v','X','p','*','h'])

# %%
sns.relplot(data=df,kind='line')

# %%
sns.relplot(data=df,x='FTWG',y='xG',hue="FTWG",s = 200)

# %%
sns.scatterplot(data=df,x='xG',y='FTWG',hue="xG",style='WDL',s =100)

# %%
sns.scatterplot(data=df,x='xGA',y='FTWG',hue="xGA",style='WDL',s =100)

# %%
sns.lmplot(data=df, x="FTWG", y="xG", col="WDL", hue="WDL",markers=['o','v','x'],scatter_kws={'s':100})

# %%
sns.lmplot(data=df, x="xGA", y="xG", col="WDL", hue="WDL",markers=['o','v','x'],scatter_kws={'s':100})

# %%
sns.lmplot(data=df, x="FTLG", y="xGA", col="WDL", hue="WDL",markers=['o','v','x'],scatter_kws={'s':100})

# %%
sns.lmplot(data=df, x="FTWG", y="FTLG", col="WDL", hue="WDL",markers=['o','v','x'],scatter_kws={'s':100})

# %%
corr=df.corr()

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')

# %%
df.pivot_table(index='xG',values='FTWG')
# Out:
#       FTWG
# xG
# 0.21   0.0
# 0.57   3.0
# 0.66   0.0
# 0.82   0.0
# 1.03   1.5
# 1.06   2.0
# 1.20   3.0
# 1.33   3.0
# 1.37   2.0
# 1.45   5.0
# 1.49   1.0
# 1.52   2.0
# 1.57   2.0
# 1.59   2.0
# 1.64   2.0
# 1.75   1.0
# 1.89   2.0
# 1.97   1.0
# 2.01   2.0
# 2.07   1.0
# 2.18   1.0
# 2.19   2.0
# 2.22   1.0
# 2.23   4.0
# 2.39   2.0
# 2.41   5.0
# 2.48   3.0
# 2.57   4.0
# 2.60   2.0
# 2.62   3.0
# 2.79   3.0
# 2.93   3.0
# 3.04   3.0
# 3.05   2.0
# 3.72   4.0
# 3.75   2.0
# 3.77   4.0

# %%
heatmap=df.pivot_table(index='xG',values='FTWG')

# %%
sns.heatmap(heatmap,cmap='coolwarm')

# %%
sns.heatmap(heatmap,cmap='coolwarm',linewidths=1,linecolor='green')

# %%
sns.boxenplot(x=df.FTHG,y=df.xG)

# %%
date=df['Date']
ft_goals=df['FTWG']
plt.plot_date(date, ft_goals, linestyle='solid')

# %%
xG_w=df['xG']
date1=df['Date']
plt.plot_date(date1,xG_w, linestyle='solid')

# %%
date=df['Date']
ft_goals=df['FTLG']
plt.plot_date(date, ft_goals, linestyle='solid')

# %%
xG_w=df['xGA']
date1=df['Date']
plt.plot_date(date1,xG_w, linestyle='solid')

# %%
xG_w=df['WDL']
date1=df['Date']
plt.plot_date(date1,xG_w, linestyle='solid')

# %%
df0=df.pivot_table(index='FTWG',columns='Date',values='xG')
df0
# Out:
# Date  01-02-2020  02-01-2020  02-07-2020  02-11-2019  04-12-2019  05-07-2020  \
# FTWG
# 0            NaN         NaN        0.82         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN        3.05         NaN        2.39         NaN        1.06
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4           3.72         NaN         NaN         NaN         NaN         NaN
# 5            NaN         NaN         NaN         NaN        2.41         NaN
#
# Date  05-10-2019  07-03-2020  07-12-2019  08-07-2020  ...  24-08-2019  \
# FTWG                                                  ...
# 0            NaN         NaN         NaN         NaN  ...         NaN
# 1            NaN         NaN         NaN         NaN  ...         NaN
# 2           3.75        1.89         NaN         NaN  ...         NaN
# 3            NaN         NaN        3.04        2.62  ...        2.79
# 4            NaN         NaN         NaN         NaN  ...         NaN
# 5            NaN         NaN         NaN         NaN  ...         NaN
#
# Date  26-07-2020  26-12-2019  27-10-2019  28-09-2019  29-01-2020  29-02-2020  \
# FTWG
# 0            NaN         NaN         NaN         NaN         NaN        0.21
# 1            NaN         NaN         NaN        1.97         NaN         NaN
# 2            NaN         NaN        2.19         NaN         2.6         NaN
# 3           0.57         NaN         NaN         NaN         NaN         NaN
# 4            NaN        3.77         NaN         NaN         NaN         NaN
# 5            NaN         NaN         NaN         NaN         NaN         NaN
#
# Date  29-12-2019  30-11-2019  31-08-2019
# FTWG
# 0            NaN         NaN         NaN
# 1           1.49         NaN         NaN
# 2            NaN        1.37         NaN
# 3            NaN         NaN         1.2
# 4            NaN         NaN         NaN
# 5            NaN         NaN         NaN
#
# [6 rows x 38 columns]

# %%
sns.heatmap(df0,cmap='coolwarm')

# %%
xG=df['xG']
date=df['Date']
plt.bar(date, xG, color ='blue', 
        width = 1)
plt.xlabel("xG Time Analysis")
plt.ylabel("Date")
plt.title("xG")
# Out:
# Text(0.5, 1.0, 'xG')

# %%
Goals = df['FTWG']
date=df['Date']
plt.bar(date, Goals, color ='blue', 
        width = 1)
plt.xlabel("Goals Scored Time Analysis")
plt.ylabel("Date")
plt.title("Goals Scored")
# Out:
# Text(0.5, 1.0, 'Goals Scored')

# %%
Goals = df['FTLG']
date=df['Date']
plt.bar(date, Goals, color ='red', 
        width = 1)
plt.xlabel("Goals Scored Time Analysis")
plt.ylabel("Date")
plt.title("Goals Conceded")
# Out:
# Text(0.5, 1.0, 'Goals Conceded')

# %%
Goals = df['xGA']
date=df['Date']
plt.bar(date, Goals, color ='red', 
        width = 1)
plt.xlabel("Goals Scored Time Analysis")
plt.ylabel("Date")
plt.title("Goals Conceded xGA")
# Out:
# Text(0.5, 1.0, 'Goals Conceded xGA')

# %%
xG=df['xGA']
Goals = df['FTLG']
date=df['Date']
plt.bar(date, Goals, color ='blue', 
        width = 1)
plt.xlabel("Goals Scored Time Analysis")
plt.ylabel("Date")
plt.title("Goals Conceded")
# Out:
# Text(0.5, 1.0, 'Goals Conceded')

# %%
xG_l=df['WDL']
date1=df['Date']
plt.plot_date(date1,xG_l, linestyle='solid')

# %%
df11=df.pivot_table(index='Date',columns='FTWG',values='xG')
df11
# Out:
# FTWG           0     1     2     3     4     5
# Date
# 01-02-2020   NaN   NaN   NaN   NaN  3.72   NaN
# 02-01-2020   NaN   NaN  3.05   NaN   NaN   NaN
# 02-07-2020  0.82   NaN   NaN   NaN   NaN   NaN
# 02-11-2019   NaN   NaN  2.39   NaN   NaN   NaN
# 04-12-2019   NaN   NaN   NaN   NaN   NaN  2.41
# 05-07-2020   NaN   NaN  1.06   NaN   NaN   NaN
# 05-10-2019   NaN   NaN  3.75   NaN   NaN   NaN
# 07-03-2020   NaN   NaN  1.89   NaN   NaN   NaN
# 07-12-2019   NaN   NaN   NaN  3.04   NaN   NaN
# 08-07-2020   NaN   NaN   NaN  2.62   NaN   NaN
# 09-08-2019   NaN   NaN   NaN   NaN  2.23   NaN
# 10-11-2019   NaN   NaN   NaN  1.33   NaN   NaN
# 11-01-2020   NaN  1.75   NaN   NaN   NaN   NaN
# 11-07-2020   NaN  2.18   NaN   NaN   NaN   NaN
# 14-09-2019   NaN   NaN   NaN  2.93   NaN   NaN
# 14-12-2019   NaN   NaN  1.57   NaN   NaN   NaN
# 15-02-2020   NaN  2.07   NaN   NaN   NaN   NaN
# 15-07-2020   NaN  2.22   NaN   NaN   NaN   NaN
# 17-08-2019   NaN   NaN  1.52   NaN   NaN   NaN
# 19-01-2020   NaN   NaN  2.01   NaN   NaN   NaN
# 20-10-2019   NaN  1.03   NaN   NaN   NaN   NaN
# 21-06-2020  0.66   NaN   NaN   NaN   NaN   NaN
# 22-07-2020   NaN   NaN   NaN   NaN   NaN  1.45
# 22-09-2019   NaN   NaN  1.03   NaN   NaN   NaN
# 23-01-2020   NaN   NaN  1.59   NaN   NaN   NaN
# 23-11-2019   NaN   NaN  1.64   NaN   NaN   NaN
# 24-02-2020   NaN   NaN   NaN  2.48   NaN   NaN
# 24-06-2020   NaN   NaN   NaN   NaN  2.57   NaN
# 24-08-2019   NaN   NaN   NaN  2.79   NaN   NaN
# 26-07-2020   NaN   NaN   NaN  0.57   NaN   NaN
# 26-12-2019   NaN   NaN   NaN   NaN  3.77   NaN
# 27-10-2019   NaN   NaN  2.19   NaN   NaN   NaN
# 28-09-2019   NaN  1.97   NaN   NaN   NaN   NaN
# 29-01-2020   NaN   NaN  2.60   NaN   NaN   NaN
# 29-02-2020  0.21   NaN   NaN   NaN   NaN   NaN
# 29-12-2019   NaN  1.49   NaN   NaN   NaN   NaN
# 30-11-2019   NaN   NaN  1.37   NaN   NaN   NaN
# 31-08-2019   NaN   NaN   NaN  1.20   NaN   NaN

# %%
sns.heatmap(df11,cmap=('coolwarm'))

# %%
df01=df.pivot_table(index='Date',columns='FTLG',values='xGA')
df01
# Out:
# FTLG           0     1     2     3     4
# Date
# 01-02-2020  0.72   NaN   NaN   NaN   NaN
# 02-01-2020  0.63   NaN   NaN   NaN   NaN
# 02-07-2020   NaN   NaN   NaN   NaN  2.65
# 02-11-2019   NaN  0.74   NaN   NaN   NaN
# 04-12-2019   NaN   NaN  1.76   NaN   NaN
# 05-07-2020  0.69   NaN   NaN   NaN   NaN
# 05-10-2019   NaN  0.10   NaN   NaN   NaN
# 07-03-2020   NaN  1.30   NaN   NaN   NaN
# 07-12-2019  0.15   NaN   NaN   NaN   NaN
# 08-07-2020   NaN  2.36   NaN   NaN   NaN
# 09-08-2019   NaN  0.84   NaN   NaN   NaN
# 10-11-2019   NaN  1.48   NaN   NaN   NaN
# 11-01-2020  1.11   NaN   NaN   NaN   NaN
# 11-07-2020   NaN  0.45   NaN   NaN   NaN
# 14-09-2019   NaN  0.29   NaN   NaN   NaN
# 14-12-2019  1.01   NaN   NaN   NaN   NaN
# 15-02-2020  0.38   NaN   NaN   NaN   NaN
# 15-07-2020   NaN   NaN  1.32   NaN   NaN
# 17-08-2019   NaN  2.14   NaN   NaN   NaN
# 19-01-2020  1.42   NaN   NaN   NaN   NaN
# 20-10-2019   NaN  0.79   NaN   NaN   NaN
# 21-06-2020  0.62   NaN   NaN   NaN   NaN
# 22-07-2020   NaN   NaN   NaN  2.38   NaN
# 22-09-2019   NaN  1.23   NaN   NaN   NaN
# 23-01-2020   NaN  1.85   NaN   NaN   NaN
# 23-11-2019   NaN  1.02   NaN   NaN   NaN
# 24-02-2020   NaN   NaN  0.64   NaN   NaN
# 24-06-2020  0.06   NaN   NaN   NaN   NaN
# 24-08-2019   NaN  0.99   NaN   NaN   NaN
# 26-07-2020   NaN  0.34   NaN   NaN   NaN
# 26-12-2019  0.12   NaN   NaN   NaN   NaN
# 27-10-2019   NaN  1.35   NaN   NaN   NaN
# 28-09-2019  1.17   NaN   NaN   NaN   NaN
# 29-01-2020  0.88   NaN   NaN   NaN   NaN
# 29-02-2020   NaN   NaN   NaN  0.21   NaN
# 29-12-2019  0.36   NaN   NaN   NaN   NaN
# 30-11-2019   NaN  0.87   NaN   NaN   NaN
# 31-08-2019  0.62   NaN   NaN   NaN   NaN

# %%
sns.heatmap(df01,cmap='coolwarm')

# %%
df011=df.pivot_table(index='FTLG',columns='Date',values='xGA')
df011
# Out:
# Date  01-02-2020  02-01-2020  02-07-2020  02-11-2019  04-12-2019  05-07-2020  \
# FTLG
# 0           0.72        0.63         NaN         NaN         NaN        0.69
# 1            NaN         NaN         NaN        0.74         NaN         NaN
# 2            NaN         NaN         NaN         NaN        1.76         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN        2.65         NaN         NaN         NaN
#
# Date  05-10-2019  07-03-2020  07-12-2019  08-07-2020  ...  24-08-2019  \
# FTLG                                                  ...
# 0            NaN         NaN        0.15         NaN  ...         NaN
# 1            0.1         1.3         NaN        2.36  ...        0.99
# 2            NaN         NaN         NaN         NaN  ...         NaN
# 3            NaN         NaN         NaN         NaN  ...         NaN
# 4            NaN         NaN         NaN         NaN  ...         NaN
#
# Date  26-07-2020  26-12-2019  27-10-2019  28-09-2019  29-01-2020  29-02-2020  \
# FTLG
# 0            NaN        0.12         NaN        1.17        0.88         NaN
# 1           0.34         NaN        1.35         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN        0.21
# 4            NaN         NaN         NaN         NaN         NaN         NaN
#
# Date  29-12-2019  30-11-2019  31-08-2019
# FTLG
# 0           0.36         NaN        0.62
# 1            NaN        0.87         NaN
# 2            NaN         NaN         NaN
# 3            NaN         NaN         NaN
# 4            NaN         NaN         NaN
#
# [5 rows x 38 columns]

# %%
sns.heatmap(df011,cmap='coolwarm')

# %%
df_xG=df.xG
df_xGA=df.xGA
df_xG_Diff=df_xG-df_xGA

print((df_xG_Diff).to_string(index=False),"\n\n",(df.WDL).to_string(index=False))
# Out:
#  1.39
# -0.62
#  1.80
#  0.58
#  2.64
# -0.20
#  0.80
#  3.65
#  0.24
#  0.84
#  1.65
# -0.15
#  0.62
#  0.50
#  0.65
#  2.89
#  0.56
#  3.65
#  1.13
#  2.42
#  0.64
#  0.59
# -0.26
#  1.72
#  3.00
#  1.69
#  1.84
#  0.00
#  0.59
#  0.04
#  2.51
# -1.83
#  0.37
#  0.26
#  1.73
#  0.90
# -0.93
#  0.23
#
#   W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  D
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  L
#  W
#  D
#  W
#  L
#  W
#  W
#  D
#  L
#  W
#  W

# %%
pos_count=0
neg_count =0
null_count=0
for i in df_xG_Diff:
    if i > 0: 
        pos_count += 1
    elif i < 0: 
        neg_count += 1
    else:
        null_count+=1
print("Positive xG in 38 matches: ",pos_count)
print("Negative xG in 38 matches: ",neg_count)
print("Null Difference in xG in 38 matches: ",null_count)
# Out:
# Positive xG in 38 matches:  31
# Negative xG in 38 matches:  6
# Null Difference in xG in 38 matches:  1

# %%
df_FTWG=df.FTWG
df_FTLG=df.FTLG
df_GD=df_FTWG-df_FTLG
print((df_GD).to_string(index=False),"\n\n\n",df.WDL)
# Out:
#  3
#  1
#  2
#  3
#  2
#  1
#  1
#  1
#  0
#  1
#  1
#  2
#  1
#  1
#  3
#  3
#  2
#  4
#  1
#  2
#  1
#  2
#  1
#  2
#  4
#  1
#  1
# -3
#  1
#  0
#  4
# -4
#  2
#  2
#  0
# -1
#  2
#  2
#
#
#  0     W
# 1     W
# 2     W
# 3     W
# 4     W
# 5     W
# 6     W
# 7     W
# 8     D
# 9     W
# 10    W
# 11    W
# 12    W
# 13    W
# 14    W
# 15    W
# 16    W
# 17    W
# 18    W
# 19    W
# 20    W
# 21    W
# 22    W
# 23    W
# 24    W
# 25    W
# 26    W
# 27    L
# 28    W
# 29    D
# 30    W
# 31    L
# 32    W
# 33    W
# 34    D
# 35    L
# 36    W
# 37    W
# Name: WDL, dtype: object

# %%
pos_count=0
neg_count =0
null_count=0
for i in df_GD:
    if i > 0: 
        pos_count += 1
    elif i < 0: 
        neg_count += 1
    else:
        null_count+=1
print("Positive GD in 38 matches i.e. Wins: ",pos_count)
print("Negative GD in 38 matches i.e. Loss: ",neg_count)
print("Null Difference in GD in 38 matches i.e. Draws: ",null_count)
# Out:
# Positive GD in 38 matches i.e. Wins:  32
# Negative GD in 38 matches i.e. Loss:  3
# Null Difference in GD in 38 matches i.e. Draws:  3

# %%
df_PPDA=df.PPDA
df_aPPDA=df.aPPDA
df_PPDA_Diff=df_PPDA-df_aPPDA
print((df_PPDA_Diff).to_string(index=False),df.WDL)
# Out:
# -15.51
#  -2.57
# -18.65
# -10.05
# -34.94
#  -3.72
# -12.97
#  -1.47
# -26.33
# -27.23
#  16.53
#   8.41
# -11.81
#  -0.14
#   0.68
# -34.57
# -12.73
#  -9.04
# -15.06
# -18.10
# -17.64
#  -4.00
# -10.49
# -30.88
#  -6.51
# -37.28
# -30.34
# -21.55
# -15.54
# -14.50
# -74.00
# -15.68
# -17.10
# -12.27
# -14.78
# -12.21
#  -2.65
# -13.17 0     W
# 1     W
# 2     W
# 3     W
# 4     W
# 5     W
# 6     W
# 7     W
# 8     D
# 9     W
# 10    W
# 11    W
# 12    W
# 13    W
# 14    W
# 15    W
# 16    W
# 17    W
# 18    W
# 19    W
# 20    W
# 21    W
# 22    W
# 23    W
# 24    W
# 25    W
# 26    W
# 27    L
# 28    W
# 29    D
# 30    W
# 31    L
# 32    W
# 33    W
# 34    D
# 35    L
# 36    W
# 37    W
# Name: WDL, dtype: object

# %%
pos_count=0
neg_count =0
null_count=0
for i in df_PPDA_Diff:
    if i > 0: 
        pos_count += 1
    elif i < 0: 
        neg_count += 1
    else:
        null_count+=1
print("Positive PPDA in 38 matches : ",pos_count)
print("Negative PPDA in 38 matches : ",neg_count)
print("Null Difference in PPDA in 38 matches : ",null_count)
# Out:
# Positive PPDA in 38 matches :  3
# Negative PPDA in 38 matches :  35
# Null Difference in PPDA in 38 matches :  0

# %%
df.plot(x="Date", y=["FTWG", "xG"], kind="barh",figsize=(10,15))

# %%
df.WDL
# Out:
# 0     W
# 1     W
# 2     W
# 3     W
# 4     W
# 5     W
# 6     W
# 7     W
# 8     D
# 9     W
# 10    W
# 11    W
# 12    W
# 13    W
# 14    W
# 15    W
# 16    W
# 17    W
# 18    W
# 19    W
# 20    W
# 21    W
# 22    W
# 23    W
# 24    W
# 25    W
# 26    W
# 27    L
# 28    W
# 29    D
# 30    W
# 31    L
# 32    W
# 33    W
# 34    D
# 35    L
# 36    W
# 37    W
# Name: WDL, dtype: object

# %%
df.plot.line(x='Date',y='FTWG',lw=3,color='r',figsize=(12,3))

# %%
sns.lineplot(data=df.FTWG, color="r",lw=5)
ax2 = plt.twinx()
sns.lineplot(data=df.xG, color="b", ax=ax2,lw=1)

# %%
sns.lineplot(data=df.FTLG, color="r",lw=5)
ax2 = plt.twinx()
sns.lineplot(data=df.xGA, color="b", ax=ax2,lw=1)

# %%
labels=np.array(['FTWG','FTLG','xG','xGA'])
stats=df.loc[25,labels].values
angles=np.linspace(0, 2*np.pi, len(labels), endpoint=False)
# close the plot
stats=np.concatenate((stats,[stats[0]]))
angles=np.concatenate((angles,[angles[0]]))

# %%
fig=plt.figure()
ax = fig.add_subplot(111, polar=True)  
ax.plot(angles, stats, 'o-', linewidth=2)  
ax.fill(angles, stats, alpha=0.25) 
ax.set_thetagrids(angles * 180/np.pi, labels) 
ax.set_title([df.loc[25,"HomeTeam"]]) 
#ax.set_rlim(0,250)
ax.grid(True)

#For 36th Match of Leicester City

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme()

# %%
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\Karthik Garimella\Desktop\Project\Dataset\2016+2017 Data Analysis.csv')

# %%
df
# Out:
#     Index W/D/L  GD  xG Diff  PPDA Diff  Points/Game  Wins  Losses  Draws  \
# 0       1     W   1     1.01      -5.63         2.44  30.0     5.0    3.0
# 1       2     W   1     0.98      -1.49          NaN   NaN     NaN    NaN
# 2       3     W   3     2.68       2.35          NaN   NaN     NaN    NaN
# 3       4     D   0     0.96      -3.51          NaN   NaN     NaN    NaN
# 4       5     L  -1    -0.26       4.62          NaN   NaN     NaN    NaN
# 5       6     L  -3    -1.05       0.38          NaN   NaN     NaN    NaN
# 6       7     W   2     1.72      -3.69          NaN   NaN     NaN    NaN
# 7       8     W   3     2.94      -1.58          NaN   NaN     NaN    NaN
# 8       9     W   4     1.51       2.61          NaN   NaN     NaN    NaN
# 9      10     W   2     0.73      -5.30          NaN   NaN     NaN    NaN
# 10     11     W   5     1.93      -0.31          NaN   NaN     NaN    NaN
# 11     12     W   1     1.13      -2.11          NaN   NaN     NaN    NaN
# ...

# %% [markdown]
# x% of goals scored came from open play, corners,pens,etc to show how much did they rely on things

# %% [markdown]
# x% of goals conceded came from open play,corners,etc to show they defensively resolute the teams were

# %%
labels=np.array(['Wins','Losses','Draws','FTWG','xG','FTLG','xGA','Points','xPoints'])
stats=df.loc[0,labels].values
angles=np.linspace(0, 2*np.pi, len(labels), endpoint=False)
# close the plot
stats=np.concatenate((stats,[stats[0]]))
angles=np.concatenate((angles,[angles[0]]))

# %%
fig=plt.figure()
ax = fig.add_subplot(111, polar=True)  
ax.plot(angles, stats, 'o-', linewidth=2)  
ax.fill(angles, stats, alpha=0.25) 
ax.set_thetagrids(angles * 180/np.pi, labels) 
ax.set_title([df.loc[0,"Index"]]) 
#ax.set_rlim(0,250)
# Out:
# Text(0.5, 1.05, '[1]')

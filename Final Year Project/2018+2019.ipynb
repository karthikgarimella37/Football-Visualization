# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme()

# %%
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\Karthik Garimella\Desktop\Project\Dataset\2018+2019.csv')

# %%
df
# Out:
#     Div        Date        HomeTeam        AwayTeam  FTWG  FTLG  FTHG  FTAG  \
# 0     1  12-08-2018         Arsenal        Man City     2     0     0     2
# 1     2  19-08-2018        Man City    Huddersfield     6     1     6     1
# 2     3  25-08-2018          Wolves        Man City     1     1     1     1
# 3     4  01-09-2018        Man City       Newcastle     2     1     2     1
# 4     5  15-09-2018        Man City          Fulham     3     0     3     0
# 5     6  22-09-2018         Cardiff        Man City     5     0     0     5
# 6     7  29-09-2018        Man City        Brighton     2     0     2     0
# 7     8  07-10-2018       Liverpool        Man City     0     0     0     0
# 8     9  20-10-2018        Man City         Burnley     5     0     5     0
# 9    10  29-10-2018       Tottenham        Man City     1     0     0     1
# 10   11  04-11-2018        Man City     Southampton     6     1     6     1
# 11   12  11-11-2018        Man City      Man United     3     1     3     1
# 12   13  24-11-2018        West Ham        Man City     4     0     0     4
# 13   14  01-12-2018        Man City     Bournemouth     3     1     3     1
# 14   15  04-12-2018         Watford        Man City     2     1     1     2
# 15   16  08-12-2018         Chelsea        Man City     0     2     2     0
# 16   17  15-12-2018        Man City         Everton     3     1     3     1
# 17   18  22-12-2018        Man City  Crystal Palace     2     3     2     3
# 18   19  26-12-2018       Leicester        Man City     1     2     2     1
# 19   20  30-12-2018     Southampton        Man City     3     1     1     3
# 20   21  03-01-2019        Man City       Liverpool     2     1     2     1
# 21   22  14-01-2019        Man City          Wolves     3     0     3     0
# 22   23  20-01-2019    Huddersfield        Man City     3     0     0     3
# 23   24  29-01-2019       Newcastle        Man City     1     2     2     1
# 24   25  03-02-2019        Man City         Arsenal     3     1     3     1
# 25   26  06-02-2019         Everton        Man City     2     0     0     2
# 26   27  10-02-2019        Man City         Chelsea     6     0     6     0
# 27   28  27-02-2019        Man City        West Ham     1     0     1     0
# 28   29  02-03-2019     Bournemouth        Man City     1     0     0     1
# 29   30  09-03-2019        Man City         Watford     3     1     3     1
# 30   31  30-03-2019          Fulham        Man City     2     0     0     2
# 31   32  03-04-2019        Man City         Cardiff     2     0     2     0
# 32   33  14-04-2019  Crystal Palace        Man City     3     1     1     3
# 33   34  20-04-2019        Man City       Tottenham     1     0     1     0
# 34   35  24-04-2019      Man United        Man City     2     0     0     2
# 35   36  28-04-2019         Burnley        Man City     1     0     0     1
# 36   37  06-05-2019        Man City       Leicester     1     0     1     0
# 37   38  12-05-2019        Brighton        Man City     4     1     1     4
#
#    WDL FTR  ...  HC  AC HY AY  HR  AR    xG   xGA   PPDA  aPPDA
# 0    W   A  ...   2   9  2  2   0   0  2.02  0.45  10.95  13.56
# 1    W   H  ...  10   3  0  2   0   0  4.60  0.66   9.18  35.22
# 2    D   D  ...   5   9  1  2   0   0  1.84  1.26   6.83  22.88
# 3    W   H  ...   4   0  0  0   0   0  2.47  0.55   8.82  30.46
# 4    W   H  ...  10   4  0  0   0   0  4.92  0.34  10.86  38.18
# 5    W   A  ...   1   9  1  1   0   0  3.08  0.10   7.64  67.50
# 6    W   H  ...  10   3  0  3   0   0  2.91  0.23   6.05  33.00
# 7    D   D  ...   2   6  1  3   0   0  1.07  0.43  15.14  23.13
# 8    W   H  ...  10   1  2  2   0   0  4.49  0.37   9.42  39.00
# 9    W   A  ...   3   6  2  2   0   0  1.94  0.44  10.65  13.18
# 10   W   H  ...   4   4  1  1   0   0  2.76  1.81   8.95  29.79
# 11   W   H  ...   5   1  1  1   0   0  2.03  0.97  12.63  20.21
# 12   W   A  ...   8   1  0  0   0   0  0.83  0.83  14.62  29.11
# 13   W   H  ...   8   4  0  0   0   0  2.84  0.72   6.21  67.43
# 14   W   A  ...   3  11  0  1   0   0  2.52  1.67   6.95  39.50
# 15   L   H  ...   1  13  2  0   0   0  0.74  0.53   8.34  17.57
# 16   W   H  ...   6   2  1  2   0   0  1.80  1.62   8.67  24.18
# 17   L   A  ...  13   0  0  4   0   0  1.27  1.15   4.40  24.25
# 18   L   H  ...   3   7  2  2   0   1  1.35  1.56   6.20  33.22
# 19   W   A  ...   3   8  2  3   1   0  2.37  0.22   7.44  34.62
# 20   W   H  ...   2   1  4  2   0   0  1.00  1.38  10.76  25.93
# 21   W   H  ...  12   1  1  0   0   1  3.12  0.10   6.08  43.57
# 22   W   A  ...   1   4  2  2   0   0  2.01  0.76   9.28  21.22
# 23   L   H  ...   1   8  2  3   0   0  1.34  0.99   4.46  21.26
# 24   W   H  ...   4   2  1  1   0   0  3.03  0.70   8.70  15.65
# 25   W   A  ...   5   6  1  1   0   0  2.61  0.11   8.00  15.65
# 26   W   H  ...   2   2  1  2   0   0  4.04  0.90  14.95  22.81
# 27   W   H  ...  12   2  0  2   0   0  3.68  0.40   9.50  41.11
# 28   W   A  ...   0  14  1  2   0   0  1.60  0.00   6.07  33.45
# 29   W   H  ...   9   1  1  1   0   0  3.76  0.41   8.24  38.63
# 30   W   A  ...   0  11  2  0   0   0  2.32  0.66   8.50  34.00
# 31   W   H  ...   7   4  0  3   0   0  3.54  0.14   5.19  48.71
# 32   W   A  ...   2   9  0  0   0   0  2.86  0.32   4.81  29.62
# 33   W   H  ...   4   4  1  2   0   0  2.06  1.20   6.26  16.14
# 34   W   A  ...   1   1  2  2   0   0  0.53  0.51   8.96  19.77
# 35   W   A  ...   0   6  1  1   0   0  2.35  0.09   7.36  20.13
# 36   W   H  ...  11   0  3  2   0   0  1.09  0.54   8.30  47.83
# 37   W   A  ...   2   6  0  0   0   0  2.22  0.60   6.09  28.85
#
# [38 rows x 30 columns]

# %%
df.describe()
# Out:
#              Div       FTWG       FTLG       FTHG       FTAG       HTHG  \
# count  38.000000  38.000000  38.000000  38.000000  38.000000  38.000000
# mean   19.500000   2.500000   0.605263   1.789474   1.315789   0.842105
# std    11.113055   1.572569   0.754786   1.757730   1.296675   1.078696
# min     1.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%    10.250000   1.000000   0.000000   0.000000   0.000000   0.000000
# 50%    19.500000   2.000000   0.000000   1.500000   1.000000   1.000000
# 75%    28.750000   3.000000   1.000000   3.000000   2.000000   1.000000
# max    38.000000   6.000000   3.000000   6.000000   5.000000   4.000000
#
#             HTAG         HS         AS        HST  ...         HC         AC  \
# count  38.000000  38.000000  38.000000  38.000000  ...  38.000000  38.000000
# mean    0.736842  13.394737  10.789474   5.026316  ...   4.894737   4.815789
# std     0.920758   8.448699   6.597124   3.657549  ...   3.909721   3.833390
# min     0.000000   0.000000   2.000000   0.000000  ...   0.000000   0.000000
# 25%     0.000000   6.250000   5.000000   2.000000  ...   2.000000   1.250000
# 50%     0.500000  11.500000   9.500000   5.000000  ...   4.000000   4.000000
# 75%     1.000000  19.000000  14.750000   8.000000  ...   8.000000   7.750000
# max     3.000000  32.000000  25.000000  14.000000  ...  13.000000  14.000000
#
#               HY         AY         HR         AR         xG        xGA  \
# count  38.000000  38.000000  38.000000  38.000000  38.000000  38.000000
# mean    1.078947   1.500000   0.026316   0.052632   2.395000   0.676842
# std     0.969301   1.084286   0.162221   0.226294   1.103466   0.486755
# min     0.000000   0.000000   0.000000   0.000000   0.530000   0.000000
# 25%     0.000000   1.000000   0.000000   0.000000   1.650000   0.347500
# 50%     1.000000   2.000000   0.000000   0.000000   2.335000   0.545000
# 75%     2.000000   2.000000   0.000000   0.000000   3.000000   0.952500
# max     4.000000   4.000000   1.000000   1.000000   4.920000   1.810000
#
#             PPDA      aPPDA
# count  38.000000  38.000000
# mean    8.459474  30.534737
# std     2.703904  12.922921
# min     4.400000  13.180000
# 25%     6.222500  21.230000
# 50%     8.320000  29.365000
# 75%     9.385000  37.440000
# max    15.140000  67.500000
#
# [8 rows x 23 columns]

# %%
plt.plot(df['FTWG'],df['xG'])
plt.xlabel('Goals Scored')
plt.ylabel('xG of Manchester City')
plt.title('Goal Scoring Pattern')
# Out:
# Text(0.5, 1.0, 'Goal Scoring Pattern')

# %%
plt.plot(df['xG'],df['FTWG'])
plt.xlabel('xG')
plt.ylabel('FTWG')
plt.title('Goal Scoring Pattern based on xG')
# Out:
# Text(0.5, 1.0, 'Goal Scoring Pattern based on xG')

# %%
plt.plot(df['FTLG'],df['xGA'])
plt.xlabel('Goals Scored')
plt.ylabel('xG of Manchester City')
plt.title('Goal Scoring Pattern')
# Out:
# Text(0.5, 1.0, 'Goal Scoring Pattern')

# %%
df['FTWG'].plot(kind='hist');

# %%
df['FTWG'].plot.area()

# %%
df['xG'].plot(kind='hist');

# %%
df.plot(kind='scatter',x='FTWG',y='xG',s=100,c='xG',cmap='coolwarm')

# %%
df.plot(kind='scatter',x='FTLG',y='xGA',s=100,c='xGA',cmap='coolwarm')

# %%
sns.displot(df['FTWG'],kde=True,bins=15)

# %%
sns.displot(df['FTLG'],kde=True,bins=15)

# %%
sns.displot(df['xG'],kde=True)

# %%
sns.displot(df['xGA'],kde=True,bins=15)

# %%
sns.displot(df['PPDA'],kde=True,bins=15)

# %%
sns.jointplot(x='FTWG',y='xG',data=df,s=100)

# %%
sns.jointplot(x='xG',y='xGA',data=df,kind='reg',scatter_kws={'s':100})

# %%
sns.jointplot(x='xG',y='PPDA',data=df,s=100)

# %%
sns.jointplot(x='xG',y='PPDA',data=df,s=100)

# %%
sns.jointplot(x='FTWG',y='xG',data=df,kind='reg',scatter_kws={'s':100})

# %%
sns.jointplot(x='FTLG',y='xGA',data=df,kind='reg',scatter_kws={'s':100})

# %%
sns.jointplot(x='xG',y='PPDA',data=df,kind='reg',scatter_kws={'s':100})

# %%
sns.displot(data=df, kind="ecdf", x="FTWG", rug=True)

# %%
sns.relplot(data=df,x='FTWG',y='xG',hue="FTWG",s=300)

# %%
sns.relplot(data=df,x='PPDA',y='FTWG',hue="FTWG",s=300)

# %%
sns.relplot(data=df,x='FTWG',y='xG',hue="xG",col='WDL',s=500)

# %%
sns.relplot(
    data=df, kind="line",
    x="FTWG", y="Date")

# %%
sns.relplot(
    data=df, kind="line",
    x="Date",y="FTWG" 
)

# %%
sns.relplot(
    data=df, kind="line",
    x="FTWG", y="xG"
)

# %%
sns.lmplot(data=df, x="FTWG", y="xG", col="WDL", hue="FTWG",scatter_kws={'s':100})

# %%
sns.lmplot(data=df, x="FTWG", y="xG", hue="FTWG",scatter_kws={'s':100},markers=['o','v','X','p','*','h','8'])

# %%
sns.relplot(data=df,kind='line')

# %%
sns.relplot(data=df,x='FTWG',y='xG',hue="FTWG",s = 200)

# %%
sns.scatterplot(data=df,x='xG',y='FTWG',hue="xG",style='WDL',s =100)

# %%
sns.scatterplot(data=df,x='xGA',y='FTWG',hue="xGA",style='WDL',s =100)

# %%
sns.lmplot(data=df, x="FTWG", y="xG", col="WDL", hue="WDL",markers=['o','v','x'],scatter_kws={'s':100})

# %%
sns.lmplot(data=df, x="xGA", y="xG", col="WDL", hue="WDL",markers=['o','v','x'],scatter_kws={'s':100})

# %%
sns.lmplot(data=df, x="FTLG", y="xGA", col="WDL", hue="WDL",markers=['o','v','x'],scatter_kws={'s':100})

# %%
sns.lmplot(data=df, x="FTWG", y="FTLG", col="WDL", hue="WDL",markers=['o','v','x'],scatter_kws={'s':100})

# %%
corr=df.corr()

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')

# %%
df.pivot_table(index='xG',values='FTWG')
# Out:
#       FTWG
# xG
# 0.53     2
# 0.74     0
# 0.83     4
# 1.00     2
# 1.07     0
# 1.09     1
# 1.27     2
# 1.34     1
# 1.35     1
# 1.60     1
# 1.80     3
# 1.84     1
# 1.94     1
# 2.01     3
# 2.02     2
# 2.03     3
# 2.06     1
# 2.22     4
# 2.32     2
# 2.35     1
# 2.37     3
# 2.47     2
# 2.52     2
# 2.61     2
# 2.76     6
# 2.84     3
# 2.86     3
# 2.91     2
# 3.03     3
# 3.08     5
# 3.12     3
# 3.54     2
# 3.68     1
# 3.76     3
# 4.04     6
# 4.49     5
# 4.60     6
# 4.92     3

# %%
heatmap=df.pivot_table(index='xG',values='FTWG')

# %%
sns.heatmap(heatmap,cmap='coolwarm')

# %%
sns.heatmap(heatmap,cmap='coolwarm',linewidths=1,linecolor='green')

# %%
sns.boxenplot(x=df.FTHG,y=df.xG)

# %%
date=df['Date']
ft_goals=df['FTWG']
plt.plot_date(date, ft_goals, linestyle='solid')

# %%
xG_w=df['xG']
date1=df['Date']
plt.plot_date(date1,xG_w, linestyle='solid')

# %%
date=df['Date']
ft_goals=df['FTLG']
plt.plot_date(date, ft_goals, linestyle='solid')

# %%
xG_w=df['xGA']
date1=df['Date']
plt.plot_date(date1,xG_w, linestyle='solid')

# %%
xG_w=df['WDL']
date1=df['Date']
plt.plot_date(date1,xG_w, linestyle='solid')

# %%
df0=df.pivot_table(index='FTWG',columns='Date',values='xG')
df0
# Out:
# Date  01-09-2018  01-12-2018  02-03-2019  03-01-2019  03-02-2019  03-04-2019  \
# FTWG
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         1.6         NaN         NaN         NaN
# 2           2.47         NaN         NaN         1.0         NaN        3.54
# 3            NaN        2.84         NaN         NaN        3.03         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# 5            NaN         NaN         NaN         NaN         NaN         NaN
# 6            NaN         NaN         NaN         NaN         NaN         NaN
#
# Date  04-11-2018  04-12-2018  06-02-2019  06-05-2019  ...  24-11-2018  \
# FTWG                                                  ...
# 0            NaN         NaN         NaN         NaN  ...         NaN
# 1            NaN         NaN         NaN        1.09  ...         NaN
# 2            NaN        2.52        2.61         NaN  ...         NaN
# 3            NaN         NaN         NaN         NaN  ...         NaN
# 4            NaN         NaN         NaN         NaN  ...        0.83
# 5            NaN         NaN         NaN         NaN  ...         NaN
# 6           2.76         NaN         NaN         NaN  ...         NaN
#
# Date  25-08-2018  26-12-2018  27-02-2019  28-04-2019  29-01-2019  29-09-2018  \
# FTWG
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1           1.84        1.35        3.68        2.35        1.34         NaN
# 2            NaN         NaN         NaN         NaN         NaN        2.91
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# 5            NaN         NaN         NaN         NaN         NaN         NaN
# 6            NaN         NaN         NaN         NaN         NaN         NaN
#
# Date  29-10-2018  30-03-2019  30-12-2018
# FTWG
# 0            NaN         NaN         NaN
# 1           1.94         NaN         NaN
# 2            NaN        2.32         NaN
# 3            NaN         NaN        2.37
# 4            NaN         NaN         NaN
# 5            NaN         NaN         NaN
# 6            NaN         NaN         NaN
#
# [7 rows x 38 columns]

# %%
sns.heatmap(df0,cmap='coolwarm')

# %%
xG=df['xG']
date=df['Date']
plt.bar(date, xG, color ='blue', 
        width = 1)
plt.xlabel("xG Time Analysis")
plt.ylabel("Date")
plt.title("xG")
# Out:
# Text(0.5, 1.0, 'xG')

# %%
Goals = df['FTWG']
date=df['Date']
plt.bar(date, Goals, color ='blue', 
        width = 1)
plt.xlabel("Goals Scored Time Analysis")
plt.ylabel("Date")
plt.title("Goals Scored")
# Out:
# Text(0.5, 1.0, 'Goals Scored')

# %%
Goals = df['FTLG']
date=df['Date']
plt.bar(date, Goals, color ='red', 
        width = 1)
plt.xlabel("Goals Scored Time Analysis")
plt.ylabel("Date")
plt.title("Goals Conceded")
# Out:
# Text(0.5, 1.0, 'Goals Conceded')

# %%
Goals = df['xGA']
date=df['Date']
plt.bar(date, Goals, color ='red', 
        width = 1)
plt.xlabel("Goals Scored Time Analysis")
plt.ylabel("Date")
plt.title("Goals Conceded xGA")
# Out:
# Text(0.5, 1.0, 'Goals Conceded xGA')

# %%
xG=df['xGA']
Goals = df['FTLG']
date=df['Date']
plt.bar(date, Goals, color ='blue', 
        width = 1)
plt.xlabel("Goals Scored Time Analysis")
plt.ylabel("Date")
plt.title("Goals Conceded")
# Out:
# Text(0.5, 1.0, 'Goals Conceded')

# %%
xG_l=df['WDL']
date1=df['Date']
plt.plot_date(date1,xG_l, linestyle='solid')

# %%
df11=df.pivot_table(index='Date',columns='FTWG',values='xG')
df11
# Out:
# FTWG           0     1     2     3     4     5     6
# Date
# 01-09-2018   NaN   NaN  2.47   NaN   NaN   NaN   NaN
# 01-12-2018   NaN   NaN   NaN  2.84   NaN   NaN   NaN
# 02-03-2019   NaN  1.60   NaN   NaN   NaN   NaN   NaN
# 03-01-2019   NaN   NaN  1.00   NaN   NaN   NaN   NaN
# 03-02-2019   NaN   NaN   NaN  3.03   NaN   NaN   NaN
# 03-04-2019   NaN   NaN  3.54   NaN   NaN   NaN   NaN
# 04-11-2018   NaN   NaN   NaN   NaN   NaN   NaN  2.76
# 04-12-2018   NaN   NaN  2.52   NaN   NaN   NaN   NaN
# 06-02-2019   NaN   NaN  2.61   NaN   NaN   NaN   NaN
# 06-05-2019   NaN  1.09   NaN   NaN   NaN   NaN   NaN
# 07-10-2018  1.07   NaN   NaN   NaN   NaN   NaN   NaN
# 08-12-2018  0.74   NaN   NaN   NaN   NaN   NaN   NaN
# 09-03-2019   NaN   NaN   NaN  3.76   NaN   NaN   NaN
# 10-02-2019   NaN   NaN   NaN   NaN   NaN   NaN  4.04
# 11-11-2018   NaN   NaN   NaN  2.03   NaN   NaN   NaN
# 12-05-2019   NaN   NaN   NaN   NaN  2.22   NaN   NaN
# 12-08-2018   NaN   NaN  2.02   NaN   NaN   NaN   NaN
# 14-01-2019   NaN   NaN   NaN  3.12   NaN   NaN   NaN
# 14-04-2019   NaN   NaN   NaN  2.86   NaN   NaN   NaN
# 15-09-2018   NaN   NaN   NaN  4.92   NaN   NaN   NaN
# 15-12-2018   NaN   NaN   NaN  1.80   NaN   NaN   NaN
# 19-08-2018   NaN   NaN   NaN   NaN   NaN   NaN  4.60
# 20-01-2019   NaN   NaN   NaN  2.01   NaN   NaN   NaN
# 20-04-2019   NaN  2.06   NaN   NaN   NaN   NaN   NaN
# 20-10-2018   NaN   NaN   NaN   NaN   NaN  4.49   NaN
# 22-09-2018   NaN   NaN   NaN   NaN   NaN  3.08   NaN
# 22-12-2018   NaN   NaN  1.27   NaN   NaN   NaN   NaN
# 24-04-2019   NaN   NaN  0.53   NaN   NaN   NaN   NaN
# 24-11-2018   NaN   NaN   NaN   NaN  0.83   NaN   NaN
# 25-08-2018   NaN  1.84   NaN   NaN   NaN   NaN   NaN
# 26-12-2018   NaN  1.35   NaN   NaN   NaN   NaN   NaN
# 27-02-2019   NaN  3.68   NaN   NaN   NaN   NaN   NaN
# 28-04-2019   NaN  2.35   NaN   NaN   NaN   NaN   NaN
# 29-01-2019   NaN  1.34   NaN   NaN   NaN   NaN   NaN
# 29-09-2018   NaN   NaN  2.91   NaN   NaN   NaN   NaN
# 29-10-2018   NaN  1.94   NaN   NaN   NaN   NaN   NaN
# 30-03-2019   NaN   NaN  2.32   NaN   NaN   NaN   NaN
# 30-12-2018   NaN   NaN   NaN  2.37   NaN   NaN   NaN

# %%
sns.heatmap(df11,cmap=('coolwarm'))

# %%
df01=df.pivot_table(index='Date',columns='FTLG',values='xGA')
df01
# Out:
# FTLG           0     1     2     3
# Date
# 01-09-2018   NaN  0.55   NaN   NaN
# 01-12-2018   NaN  0.72   NaN   NaN
# 02-03-2019  0.00   NaN   NaN   NaN
# 03-01-2019   NaN  1.38   NaN   NaN
# 03-02-2019   NaN  0.70   NaN   NaN
# 03-04-2019  0.14   NaN   NaN   NaN
# 04-11-2018   NaN  1.81   NaN   NaN
# 04-12-2018   NaN  1.67   NaN   NaN
# 06-02-2019  0.11   NaN   NaN   NaN
# 06-05-2019  0.54   NaN   NaN   NaN
# 07-10-2018  0.43   NaN   NaN   NaN
# 08-12-2018   NaN   NaN  0.53   NaN
# 09-03-2019   NaN  0.41   NaN   NaN
# 10-02-2019  0.90   NaN   NaN   NaN
# 11-11-2018   NaN  0.97   NaN   NaN
# 12-05-2019   NaN  0.60   NaN   NaN
# 12-08-2018  0.45   NaN   NaN   NaN
# 14-01-2019  0.10   NaN   NaN   NaN
# 14-04-2019   NaN  0.32   NaN   NaN
# 15-09-2018  0.34   NaN   NaN   NaN
# 15-12-2018   NaN  1.62   NaN   NaN
# 19-08-2018   NaN  0.66   NaN   NaN
# 20-01-2019  0.76   NaN   NaN   NaN
# 20-04-2019  1.20   NaN   NaN   NaN
# 20-10-2018  0.37   NaN   NaN   NaN
# 22-09-2018  0.10   NaN   NaN   NaN
# 22-12-2018   NaN   NaN   NaN  1.15
# 24-04-2019  0.51   NaN   NaN   NaN
# 24-11-2018  0.83   NaN   NaN   NaN
# 25-08-2018   NaN  1.26   NaN   NaN
# 26-12-2018   NaN   NaN  1.56   NaN
# 27-02-2019  0.40   NaN   NaN   NaN
# 28-04-2019  0.09   NaN   NaN   NaN
# 29-01-2019   NaN   NaN  0.99   NaN
# 29-09-2018  0.23   NaN   NaN   NaN
# 29-10-2018  0.44   NaN   NaN   NaN
# 30-03-2019  0.66   NaN   NaN   NaN
# 30-12-2018   NaN  0.22   NaN   NaN

# %%
sns.heatmap(df01,cmap='coolwarm')

# %%
df011=df.pivot_table(index='FTLG',columns='Date',values='xGA')
df011
# Out:
# Date  01-09-2018  01-12-2018  02-03-2019  03-01-2019  03-02-2019  03-04-2019  \
# FTLG
# 0            NaN         NaN         0.0         NaN         NaN        0.14
# 1           0.55        0.72         NaN        1.38         0.7         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
#
# Date  04-11-2018  04-12-2018  06-02-2019  06-05-2019  ...  24-11-2018  \
# FTLG                                                  ...
# 0            NaN         NaN        0.11        0.54  ...        0.83
# 1           1.81        1.67         NaN         NaN  ...         NaN
# 2            NaN         NaN         NaN         NaN  ...         NaN
# 3            NaN         NaN         NaN         NaN  ...         NaN
#
# Date  25-08-2018  26-12-2018  27-02-2019  28-04-2019  29-01-2019  29-09-2018  \
# FTLG
# 0            NaN         NaN         0.4        0.09         NaN        0.23
# 1           1.26         NaN         NaN         NaN         NaN         NaN
# 2            NaN        1.56         NaN         NaN        0.99         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
#
# Date  29-10-2018  30-03-2019  30-12-2018
# FTLG
# 0           0.44        0.66         NaN
# 1            NaN         NaN        0.22
# 2            NaN         NaN         NaN
# 3            NaN         NaN         NaN
#
# [4 rows x 38 columns]

# %%
sns.heatmap(df011,cmap='coolwarm')

# %%
df_xG=df.xG
df_xGA=df.xGA
df_xG_Diff=df_xG-df_xGA

print((df_xG_Diff).to_string(index=False),"\n\n",(df.WDL).to_string(index=False))
# Out:
#  1.57
#  3.94
#  0.58
#  1.92
#  4.58
#  2.98
#  2.68
#  0.64
#  4.12
#  1.50
#  0.95
#  1.06
#  0.00
#  2.12
#  0.85
#  0.21
#  0.18
#  0.12
# -0.21
#  2.15
# -0.38
#  3.02
#  1.25
#  0.35
#  2.33
#  2.50
#  3.14
#  3.28
#  1.60
#  3.35
#  1.66
#  3.40
#  2.54
#  0.86
#  0.02
#  2.26
#  0.55
#  1.62
#
#   W
#  W
#  D
#  W
#  W
#  W
#  W
#  D
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  L
#  W
#  L
#  L
#  W
#  W
#  W
#  W
#  L
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W

# %%
pos_count=0
neg_count =0
null_count=0
for i in df_xG_Diff:
    if i > 0: 
        pos_count += 1
    elif i < 0: 
        neg_count += 1
    else:
        null_count+=1
print("Positive xG in 38 matches: ",pos_count)
print("Negative xG in 38 matches: ",neg_count)
print("Null Difference in xG in 38 matches: ",null_count)
# Out:
# Positive xG in 38 matches:  35
# Negative xG in 38 matches:  2
# Null Difference in xG in 38 matches:  1

# %%
df_FTWG=df.FTWG
df_FTLG=df.FTLG
df_GD=df_FTWG-df_FTLG
print((df_GD).to_string(index=False),"\n\n\n",df.WDL)
# Out:
#  2
#  5
#  0
#  1
#  3
#  5
#  2
#  0
#  5
#  1
#  5
#  2
#  4
#  2
#  1
# -2
#  2
# -1
# -1
#  2
#  1
#  3
#  3
# -1
#  2
#  2
#  6
#  1
#  1
#  2
#  2
#  2
#  2
#  1
#  2
#  1
#  1
#  3
#
#
#  0     W
# 1     W
# 2     D
# 3     W
# 4     W
# 5     W
# 6     W
# 7     D
# 8     W
# 9     W
# 10    W
# 11    W
# 12    W
# 13    W
# 14    W
# 15    L
# 16    W
# 17    L
# 18    L
# 19    W
# 20    W
# 21    W
# 22    W
# 23    L
# 24    W
# 25    W
# 26    W
# 27    W
# 28    W
# 29    W
# 30    W
# 31    W
# 32    W
# 33    W
# 34    W
# 35    W
# 36    W
# 37    W
# Name: WDL, dtype: object

# %%
pos_count=0
neg_count =0
null_count=0
for i in df_GD:
    if i > 0: 
        pos_count += 1
    elif i < 0: 
        neg_count += 1
    else:
        null_count+=1
print("Positive GD in 38 matches i.e. Wins: ",pos_count)
print("Negative GD in 38 matches i.e. Loss: ",neg_count)
print("Null Difference in GD in 38 matches i.e. Draws: ",null_count)
# Out:
# Positive GD in 38 matches i.e. Wins:  32
# Negative GD in 38 matches i.e. Loss:  4
# Null Difference in GD in 38 matches i.e. Draws:  2

# %%
df_PPDA=df.PPDA
df_aPPDA=df.aPPDA
df_PPDA_Diff=df_PPDA-df_aPPDA
print((df_PPDA_Diff).to_string(index=False),df.WDL)
# Out:
#  -2.61
# -26.04
# -16.05
# -21.64
# -27.32
# -59.86
# -26.95
#  -7.99
# -29.58
#  -2.53
# -20.84
#  -7.58
# -14.49
# -61.22
# -32.55
#  -9.23
# -15.51
# -19.85
# -27.02
# -27.18
# -15.17
# -37.49
# -11.94
# -16.80
#  -6.95
#  -7.65
#  -7.86
# -31.61
# -27.38
# -30.39
# -25.50
# -43.52
# -24.81
#  -9.88
# -10.81
# -12.77
# -39.53
# -22.76 0     W
# 1     W
# 2     D
# 3     W
# 4     W
# 5     W
# 6     W
# 7     D
# 8     W
# 9     W
# 10    W
# 11    W
# 12    W
# 13    W
# 14    W
# 15    L
# 16    W
# 17    L
# 18    L
# 19    W
# 20    W
# 21    W
# 22    W
# 23    L
# 24    W
# 25    W
# 26    W
# 27    W
# 28    W
# 29    W
# 30    W
# 31    W
# 32    W
# 33    W
# 34    W
# 35    W
# 36    W
# 37    W
# Name: WDL, dtype: object

# %%
pos_count=0
neg_count =0
null_count=0
for i in df_PPDA_Diff:
    if i > 0: 
        pos_count += 1
    elif i < 0: 
        neg_count += 1
    else:
        null_count+=1
print("Positive PPDA in 38 matches : ",pos_count)
print("Negative PPDA in 38 matches : ",neg_count)
print("Null Difference in PPDA in 38 matches : ",null_count)
# Out:
# Positive PPDA in 38 matches :  0
# Negative PPDA in 38 matches :  38
# Null Difference in PPDA in 38 matches :  0

# %%
df.WDL
# Out:
# 0     W
# 1     W
# 2     D
# 3     W
# 4     W
# 5     W
# 6     W
# 7     D
# 8     W
# 9     W
# 10    W
# 11    W
# 12    W
# 13    W
# 14    W
# 15    L
# 16    W
# 17    L
# 18    L
# 19    W
# 20    W
# 21    W
# 22    W
# 23    L
# 24    W
# 25    W
# 26    W
# 27    W
# 28    W
# 29    W
# 30    W
# 31    W
# 32    W
# 33    W
# 34    W
# 35    W
# 36    W
# 37    W
# Name: WDL, dtype: object

# %%
df.plot.line(x='Date',y='FTWG',lw=3,color='r',figsize=(12,3))

# %%
sns.lineplot(data=df.FTWG, color="r",lw=5)
ax2 = plt.twinx()
sns.lineplot(data=df.xG, color="b", ax=ax2,lw=1)

# %%
sns.lineplot(data=df.FTLG, color="r",lw=5)
ax2 = plt.twinx()
sns.lineplot(data=df.xGA, color="b", ax=ax2,lw=1)

# %%
labels=np.array(['FTWG','FTLG','xG','xGA'])
stats=df.loc[25,labels].values
angles=np.linspace(0, 2*np.pi, len(labels), endpoint=False)
# close the plot
stats=np.concatenate((stats,[stats[0]]))
angles=np.concatenate((angles,[angles[0]]))

# %%
fig=plt.figure()
ax = fig.add_subplot(111, polar=True)  
ax.plot(angles, stats, 'o-', linewidth=2)  
ax.fill(angles, stats, alpha=0.25) 
ax.set_thetagrids(angles * 180/np.pi, labels) 
ax.set_title([df.loc[25,"HomeTeam"]]) 
#ax.set_rlim(0,250)
ax.grid(True)

#For 36th Match of Leicester City

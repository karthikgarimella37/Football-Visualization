# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme()

# %%
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\Karthik Garimella\Desktop\Project\Dataset\2016+2017.csv')

# %%
df
# Out:
#     Div        Date        HomeTeam        AwayTeam  Unnamed: 4  FTWG  FTLG  \
# 0     1  15-08-2016         Chelsea        West Ham         NaN     2     1
# 1     2  20-08-2016         Watford         Chelsea         NaN     2     1
# 2     3  27-08-2016         Chelsea         Burnley         NaN     3     0
# 3     4  11-09-2016         Swansea         Chelsea         NaN     2     2
# 4     5  16-09-2016         Chelsea       Liverpool         NaN     1     2
# 5     6  24-09-2016         Arsenal         Chelsea         NaN     0     3
# 6     7  01-10-2016            Hull         Chelsea         NaN     2     0
# 7     8  15-10-2016         Chelsea       Leicester         NaN     3     0
# 8     9  23-10-2016         Chelsea      Man United         NaN     4     0
# 9    10  30-10-2016     Southampton         Chelsea         NaN     2     0
# 10   11  05-11-2016         Chelsea         Everton         NaN     5     0
# 11   12  20-11-2016   Middlesbrough         Chelsea         NaN     1     0
# 12   13  26-11-2016         Chelsea       Tottenham         NaN     2     1
# 13   14  03-12-2016        Man City         Chelsea         NaN     3     1
# 14   15  11-12-2016         Chelsea       West Brom         NaN     1     0
# 15   16  14-12-2016      Sunderland         Chelsea         NaN     1     0
# 16   17  17-12-2016  Crystal Palace         Chelsea         NaN     1     0
# 17   18  26-12-2016         Chelsea     Bournemouth         NaN     3     0
# 18   19  31-12-2016         Chelsea           Stoke         NaN     4     2
# 19   20  04-01-2017       Tottenham         Chelsea         NaN     0     2
# 20   21  14-01-2017       Leicester         Chelsea         NaN     3     0
# 21   22  22-01-2017         Chelsea            Hull         NaN     2     0
# 22   23  31-01-2017       Liverpool         Chelsea         NaN     1     1
# 23   24  04-02-2017         Chelsea         Arsenal         NaN     3     1
# 24   25  12-02-2017         Burnley         Chelsea         NaN     1     1
# 25   26  25-02-2017         Chelsea         Swansea         NaN     3     1
# 26   27  06-03-2017        West Ham         Chelsea         NaN     2     1
# 27   28  18-03-2017           Stoke         Chelsea         NaN     2     1
# 28   29  01-04-2017         Chelsea  Crystal Palace         NaN     1     2
# 29   30  05-04-2017         Chelsea        Man City         NaN     2     1
# 30   31  08-04-2017     Bournemouth         Chelsea         NaN     3     1
# 31   32  16-04-2017      Man United         Chelsea         NaN     0     2
# 32   33  25-04-2017         Chelsea     Southampton         NaN     4     2
# 33   34  30-04-2017         Everton         Chelsea         NaN     3     0
# 34   35  08-05-2017         Chelsea   Middlesbrough         NaN     3     0
# 35   36  12-05-2017       West Brom         Chelsea         NaN     1     0
# 36   37  15-05-2017         Chelsea         Watford         NaN     4     3
# 37   38  21-05-2017         Chelsea      Sunderland         NaN     5     1
#
#     FTHG  FTAG FTR  ...  HC  AC HY AY HR  AR    xG   xGA   PPDA  aPPDA
# 0      2     1   H  ...   7   1  5  2  0   0  1.46  0.45   6.26  11.89
# 1      1     2   A  ...   0   5  4  3  0   0  1.78  0.80   8.38   9.87
# 2      3     0   H  ...   9   5  2  2  0   0  2.86  0.18  16.64  14.29
# 3      2     2   D  ...   1  11  3  4  0   0  2.19  1.23  10.25  13.76
# 4      1     2   A  ...   6   4  1  1  0   0  1.16  1.42  14.71  10.09
# 5      3     0   H  ...   9   1  0  2  0   0  0.61  1.66  11.80  11.42
# 6      0     2   A  ...   5   7  2  2  0   0  1.99  0.27  11.10  14.79
# 7      3     0   H  ...   8   5  1  1  0   0  3.12  0.18  11.22  12.80
# 8      4     0   H  ...   5   7  3  2  0   0  2.25  0.74   9.08   6.47
# 9      0     2   A  ...   7   3  0  0  0   0  1.15  0.42   7.17  12.47
# 10     5     0   H  ...   4   2  0  3  0   0  1.94  0.01  13.05  13.36
# 11     0     1   A  ...   2   3  2  3  0   0  1.69  0.56  10.31  12.42
# 12     2     1   H  ...   3   8  2  1  0   0  1.25  0.42   9.15   6.27
# 13     1     3   A  ...   9   2  2  3  2   0  1.28  2.24  13.48   5.71
# 14     1     0   H  ...   3   1  2  4  0   0  0.55  0.21   5.86  10.69
# 15     0     1   A  ...   5   5  3  2  0   0  1.22  0.47   8.71  16.72
# 16     0     1   A  ...   5   3  2  3  0   0  0.81  0.36  12.52   9.14
# 17     3     0   H  ...   5   5  1  1  0   0  1.71  0.65  13.37   9.57
# 18     4     2   H  ...   8   3  3  2  0   0  1.95  0.86   8.00  19.92
# 19     2     0   H  ...   1   6  3  2  0   0  0.91  1.01  13.42  11.07
# 20     0     3   A  ...   3   5  1  0  0   0  0.74  0.18   8.25  21.71
# 21     2     0   H  ...   9   7  1  3  0   0  1.47  0.31  15.24   9.61
# 22     1     1   D  ...   3   3  2  1  0   0  1.07  1.20  11.39   6.39
# 23     3     1   H  ...  10  13  1  1  0   0  1.95  0.95   7.94   9.00
# 24     1     1   D  ...   1   1  3  2  0   0  0.80  0.91   5.55  16.29
# 25     3     1   H  ...   8   1  1  3  0   0  1.23  0.28  10.43  15.30
# 26     1     2   A  ...   6   4  0  1  0   0  2.01  0.45  15.86  13.08
# 27     1     2   A  ...   5  11  4  2  1   0  1.96  0.95   4.96  11.88
# 28     1     2   A  ...   9   3  3  2  0   0  3.17  1.57   4.43  13.29
# 29     2     1   H  ...   2   9  1  3  0   0  1.37  2.26  16.95   9.96
# 30     1     3   A  ...   4   4  2  3  0   0  1.52  0.38  18.13  14.20
# 31     2     0   H  ...   1   3  3  3  0   0  0.13  0.81   4.92   6.49
# 32     4     2   H  ...   6   7  2  2  0   0  1.44  1.33  20.43  14.94
# 33     0     3   A  ...   2   4  3  4  0   0  1.82  0.68  16.19   9.52
# 34     3     0   H  ...   8   1  0  2  0   0  2.28  0.07  22.46  10.42
# 35     0     1   A  ...   5   8  3  0  0   0  1.77  0.53  13.89  21.42
# 36     4     3   H  ...   8   3  2  4  0   1  2.65  0.88  16.55  11.04
# 37     5     1   H  ...  11   1  1  1  0   0  2.74  0.69  10.35  12.80
#
# [38 rows x 31 columns]

# %%
df.describe()
# Out:
#              Div  Unnamed: 4       FTWG       FTLG       FTHG       FTAG  \
# count  38.000000         0.0  38.000000  38.000000  38.000000  38.000000
# mean   19.500000         NaN   2.236842   0.868421   1.868421   1.236842
# std    11.113055         NaN   1.303513   0.905570   1.491798   1.024938
# min     1.000000         NaN   0.000000   0.000000   0.000000   0.000000
# 25%    10.250000         NaN   1.000000   0.000000   1.000000   0.000000
# 50%    19.500000         NaN   2.000000   1.000000   2.000000   1.000000
# 75%    28.750000         NaN   3.000000   1.000000   3.000000   2.000000
# max    38.000000         NaN   5.000000   3.000000   5.000000   3.000000
#
#             HTHG       HTAG         HS         AS  ...         HC         AC  \
# count  38.000000  38.000000  38.000000  38.000000  ...  38.000000  38.000000
# mean    0.894737   0.578947  12.736842  11.000000  ...   5.342105   4.605263
# std     0.894109   0.642275   5.838753   5.986471  ...   2.970816   3.062762
# min     0.000000   0.000000   5.000000   1.000000  ...   0.000000   1.000000
# 25%     0.000000   0.000000   8.250000   7.000000  ...   3.000000   3.000000
# 50%     1.000000   0.500000  12.000000   9.500000  ...   5.000000   4.000000
# 75%     1.000000   1.000000  16.000000  13.000000  ...   8.000000   6.750000
# max     3.000000   2.000000  28.000000  28.000000  ...  11.000000  13.000000
#
#               HY         AY         HR         AR         xG        xGA  \
# count  38.000000  38.000000  38.000000  38.000000  38.000000  38.000000
# mean    1.947368   2.105263   0.078947   0.026316   1.631579   0.751842
# std     1.229093   1.109893   0.358795   0.162221   0.715245   0.550591
# min     0.000000   0.000000   0.000000   0.000000   0.130000   0.010000
# 25%     1.000000   1.000000   0.000000   0.000000   1.175000   0.365000
# 50%     2.000000   2.000000   0.000000   0.000000   1.605000   0.665000
# 75%     3.000000   3.000000   0.000000   0.000000   1.982500   0.950000
# max     5.000000   4.000000   2.000000   1.000000   3.170000   2.260000
#
#             PPDA      aPPDA
# count  38.000000  38.000000
# mean   11.536842  12.106842
# std     4.443623   3.860115
# min     4.430000   5.710000
# 25%     8.282500   9.675000
# 50%    11.160000  11.885000
# 75%    14.505000  14.090000
# max    22.460000  21.710000
#
# [8 rows x 24 columns]

# %%
plt.plot(df['FTWG'],df['xG'])
plt.xlabel('Goals Scored')
plt.ylabel('xG of Chelsea')
plt.title('Goal Scoring Pattern')
# Out:
# Text(0.5, 1.0, 'Goal Scoring Pattern')

# %%
plt.plot(df['xG'],df['FTWG'])
plt.xlabel('xG')
plt.ylabel('FTWG')
plt.title('Goal Scoring Pattern based on xG')
# Out:
# Text(0.5, 1.0, 'Goal Scoring Pattern based on xG')

# %%
df['FTWG'].plot(kind='hist');

# %%
df['FTWG'].plot.area()

# %%
df['xG'].plot(kind='hist');

# %%
df.plot(kind='scatter',x='FTWG',y='xG',s=100,c='xG',cmap='coolwarm')

# %%
df.plot(kind='scatter',x='FTLG',y='xGA',s=100,c='xGA',cmap='coolwarm')

# %%
sns.displot(df['FTWG'],kde=True,bins=15)

# %%
sns.displot(df['FTLG'],kde=True,bins=15)

# %%
sns.displot(df['xG'],kde=True)

# %%
sns.displot(df['xGA'],kde=True,bins=15)

# %%
sns.displot(df['PPDA'],kde=True,bins=15)

# %%
sns.jointplot(x='FTWG',y='xG',data=df,s=100)

# %%
sns.jointplot(x='xG',y='xGA',data=df,kind='reg',scatter_kws={'s':100})

# %%
sns.jointplot(x='xG',y='PPDA',data=df,s=100)

# %%
sns.jointplot(x='FTWG',y='FTLG',data=df,s=100)

# %%
sns.jointplot(x='FTWG',y='xG',data=df,kind='reg',scatter_kws={'s':100})

# %%
sns.jointplot(x='xG',y='PPDA',data=df,kind='reg',scatter_kws={'s':100})

# %%
sns.displot(data=df, kind="ecdf", x="FTWG", rug=True)

# %%
sns.relplot(data=df,x='PPDA',y='FTWG',hue="FTWG",s=300)

# %%
sns.relplot(data=df,x='FTWG',y='xG',hue="xG",col='WDL',s=500)

# %%
sns.relplot(
    data=df, kind="line",
    x="FTWG", y="Date"
)

# %%
sns.relplot(
    data=df, kind="line",
    x="Date",y="FTWG" 
)

# %%
sns.relplot(
    data=df, kind="line",
    x="FTWG", y="xG"
)

# %%
sns.lmplot(data=df, x="FTWG", y="xG", col="WDL", hue="FTWG",scatter_kws={'s':100})

# %%
sns.lmplot(data=df, x="FTWG", y="xG", hue="FTWG",scatter_kws={'s':100},markers=['o','v','X','p','*','h'])

# %%
sns.relplot(data=df,kind='line')

# %%
sns.relplot(data=df,x='FTWG',y='xG',hue="FTWG",s = 200)

# %%
sns.scatterplot(data=df,x='xG',y='FTWG',hue="xG",style='WDL',s =100)

# %%
sns.scatterplot(data=df,x='xGA',y='FTWG',hue="xGA",style='WDL',s =100)

# %%
sns.lmplot(data=df, x="FTWG", y="xG", col="WDL", hue="WDL",markers=['o','v','x'],scatter_kws={'s':100})

# %%
sns.lmplot(data=df, x="xGA", y="xG", col="WDL", hue="WDL",markers=['o','v','x'],scatter_kws={'s':100})

# %%
sns.lmplot(data=df, x="FTLG", y="xGA", col="WDL", hue="WDL",markers=['o','v','x'],scatter_kws={'s':100})

# %%
sns.lmplot(data=df, x="FTWG", y="FTLG", col="WDL", hue="WDL",markers=['o','v','x'],scatter_kws={'s':100})

# %%
corr=df.corr()

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')

# %%
df.pivot_table(index='xG',values='FTWG')
# Out:
#       FTWG
# xG
# 0.13   0.0
# 0.55   1.0
# 0.61   0.0
# 0.74   3.0
# 0.80   1.0
# 0.81   1.0
# 0.91   0.0
# 1.07   1.0
# 1.15   2.0
# 1.16   1.0
# 1.22   1.0
# 1.23   3.0
# 1.25   2.0
# 1.28   3.0
# 1.37   2.0
# 1.44   4.0
# 1.46   2.0
# 1.47   2.0
# 1.52   3.0
# 1.69   1.0
# 1.71   3.0
# 1.77   1.0
# 1.78   2.0
# 1.82   3.0
# 1.94   5.0
# 1.95   3.5
# 1.96   2.0
# 1.99   2.0
# 2.01   2.0
# 2.19   2.0
# 2.25   4.0
# 2.28   3.0
# 2.65   4.0
# 2.74   5.0
# 2.86   3.0
# 3.12   3.0
# 3.17   1.0

# %%
heatmap=df.pivot_table(index='xG',values='FTWG')

# %%
sns.heatmap(heatmap,cmap='coolwarm')

# %%
sns.heatmap(heatmap,cmap='coolwarm',linewidths=1,linecolor='green')

# %%
sns.boxenplot(x=df.FTHG,y=df.xG)

# %%
date=df['Date']
ft_goals=df['FTWG']
plt.plot_date(date, ft_goals, linestyle='solid')

# %%
xG_w=df['xG']
date1=df['Date']
plt.plot_date(date1,xG_w, linestyle='solid')

# %%
date=df['Date']
ft_goals=df['FTLG']
plt.plot_date(date, ft_goals, linestyle='solid')

# %%
xG_w=df['xGA']
date1=df['Date']
plt.plot_date(date1,xG_w, linestyle='solid')

# %%
df0=df.pivot_table(index='FTWG',columns='Date',values='xG')
df0
# Out:
# Date  01-04-2017  01-10-2016  03-12-2016  04-01-2017  04-02-2017  05-04-2017  \
# FTWG
# 0            NaN         NaN         NaN        0.91         NaN         NaN
# 1           3.17         NaN         NaN         NaN         NaN         NaN
# 2            NaN        1.99         NaN         NaN         NaN        1.37
# 3            NaN         NaN        1.28         NaN        1.95         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# 5            NaN         NaN         NaN         NaN         NaN         NaN
#
# Date  05-11-2016  06-03-2017  08-04-2017  08-05-2017  ...  24-09-2016  \
# FTWG                                                  ...
# 0            NaN         NaN         NaN         NaN  ...        0.61
# 1            NaN         NaN         NaN         NaN  ...         NaN
# 2            NaN        2.01         NaN         NaN  ...         NaN
# 3            NaN         NaN        1.52        2.28  ...         NaN
# 4            NaN         NaN         NaN         NaN  ...         NaN
# 5           1.94         NaN         NaN         NaN  ...         NaN
#
# Date  25-02-2017  25-04-2017  26-11-2016  26-12-2016  27-08-2016  30-04-2017  \
# FTWG
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN        1.25         NaN         NaN         NaN
# 3           1.23         NaN         NaN        1.71        2.86        1.82
# 4            NaN        1.44         NaN         NaN         NaN         NaN
# 5            NaN         NaN         NaN         NaN         NaN         NaN
#
# Date  30-10-2016  31-01-2017  31-12-2016
# FTWG
# 0            NaN         NaN         NaN
# 1            NaN        1.07         NaN
# 2           1.15         NaN         NaN
# 3            NaN         NaN         NaN
# 4            NaN         NaN        1.95
# 5            NaN         NaN         NaN
#
# [6 rows x 38 columns]

# %%
sns.heatmap(df0,cmap='coolwarm')

# %%
xG=df['xG']
date=df['Date']
plt.bar(date, xG, color ='blue', 
        width = 1)
plt.xlabel("xG Time Analysis")
plt.ylabel("Date")
plt.title("xG")
# Out:
# Text(0.5, 1.0, 'xG')

# %%
Goals = df['FTWG']
date=df['Date']
plt.bar(date, Goals, color ='blue', 
        width = 1)
plt.xlabel("Goals Scored Time Analysis")
plt.ylabel("Date")
plt.title("Goals Scored")
# Out:
# Text(0.5, 1.0, 'Goals Scored')

# %%
xG=df['xGA']
Goals = df['FTLG']
date=df['Date']
plt.bar(date, Goals, color ='blue', 
        width = 1)
plt.xlabel("Goals Scored Time Analysis")
plt.ylabel("Date")
plt.title("Goals Conceded")
# Out:
# Text(0.5, 1.0, 'Goals Conceded')

# %%
xG_l=df['WDL']
date1=df['Date']
plt.plot_date(date1,xG_l, linestyle='solid')

# %%
df11=df.pivot_table(index='Date',columns='FTWG',values='xG')
df11
# Out:
# FTWG           0     1     2     3     4     5
# Date
# 01-04-2017   NaN  3.17   NaN   NaN   NaN   NaN
# 01-10-2016   NaN   NaN  1.99   NaN   NaN   NaN
# 03-12-2016   NaN   NaN   NaN  1.28   NaN   NaN
# 04-01-2017  0.91   NaN   NaN   NaN   NaN   NaN
# 04-02-2017   NaN   NaN   NaN  1.95   NaN   NaN
# 05-04-2017   NaN   NaN  1.37   NaN   NaN   NaN
# 05-11-2016   NaN   NaN   NaN   NaN   NaN  1.94
# 06-03-2017   NaN   NaN  2.01   NaN   NaN   NaN
# 08-04-2017   NaN   NaN   NaN  1.52   NaN   NaN
# 08-05-2017   NaN   NaN   NaN  2.28   NaN   NaN
# 11-09-2016   NaN   NaN  2.19   NaN   NaN   NaN
# 11-12-2016   NaN  0.55   NaN   NaN   NaN   NaN
# 12-02-2017   NaN  0.80   NaN   NaN   NaN   NaN
# 12-05-2017   NaN  1.77   NaN   NaN   NaN   NaN
# 14-01-2017   NaN   NaN   NaN  0.74   NaN   NaN
# 14-12-2016   NaN  1.22   NaN   NaN   NaN   NaN
# 15-05-2017   NaN   NaN   NaN   NaN  2.65   NaN
# 15-08-2016   NaN   NaN  1.46   NaN   NaN   NaN
# 15-10-2016   NaN   NaN   NaN  3.12   NaN   NaN
# 16-04-2017  0.13   NaN   NaN   NaN   NaN   NaN
# 16-09-2016   NaN  1.16   NaN   NaN   NaN   NaN
# 17-12-2016   NaN  0.81   NaN   NaN   NaN   NaN
# 18-03-2017   NaN   NaN  1.96   NaN   NaN   NaN
# 20-08-2016   NaN   NaN  1.78   NaN   NaN   NaN
# 20-11-2016   NaN  1.69   NaN   NaN   NaN   NaN
# 21-05-2017   NaN   NaN   NaN   NaN   NaN  2.74
# 22-01-2017   NaN   NaN  1.47   NaN   NaN   NaN
# 23-10-2016   NaN   NaN   NaN   NaN  2.25   NaN
# 24-09-2016  0.61   NaN   NaN   NaN   NaN   NaN
# 25-02-2017   NaN   NaN   NaN  1.23   NaN   NaN
# 25-04-2017   NaN   NaN   NaN   NaN  1.44   NaN
# 26-11-2016   NaN   NaN  1.25   NaN   NaN   NaN
# 26-12-2016   NaN   NaN   NaN  1.71   NaN   NaN
# 27-08-2016   NaN   NaN   NaN  2.86   NaN   NaN
# 30-04-2017   NaN   NaN   NaN  1.82   NaN   NaN
# 30-10-2016   NaN   NaN  1.15   NaN   NaN   NaN
# 31-01-2017   NaN  1.07   NaN   NaN   NaN   NaN
# 31-12-2016   NaN   NaN   NaN   NaN  1.95   NaN

# %%
sns.heatmap(df11,cmap=('coolwarm'))

# %%
df01=df.pivot_table(index='Date',columns='FTLG',values='xGA')
df01
# Out:
# FTLG           0     1     2     3
# Date
# 01-04-2017   NaN   NaN  1.57   NaN
# 01-10-2016  0.27   NaN   NaN   NaN
# 03-12-2016   NaN  2.24   NaN   NaN
# 04-01-2017   NaN   NaN  1.01   NaN
# 04-02-2017   NaN  0.95   NaN   NaN
# 05-04-2017   NaN  2.26   NaN   NaN
# 05-11-2016  0.01   NaN   NaN   NaN
# 06-03-2017   NaN  0.45   NaN   NaN
# 08-04-2017   NaN  0.38   NaN   NaN
# 08-05-2017  0.07   NaN   NaN   NaN
# 11-09-2016   NaN   NaN  1.23   NaN
# 11-12-2016  0.21   NaN   NaN   NaN
# 12-02-2017   NaN  0.91   NaN   NaN
# 12-05-2017  0.53   NaN   NaN   NaN
# 14-01-2017  0.18   NaN   NaN   NaN
# 14-12-2016  0.47   NaN   NaN   NaN
# 15-05-2017   NaN   NaN   NaN  0.88
# 15-08-2016   NaN  0.45   NaN   NaN
# 15-10-2016  0.18   NaN   NaN   NaN
# 16-04-2017   NaN   NaN  0.81   NaN
# 16-09-2016   NaN   NaN  1.42   NaN
# 17-12-2016  0.36   NaN   NaN   NaN
# 18-03-2017   NaN  0.95   NaN   NaN
# 20-08-2016   NaN  0.80   NaN   NaN
# 20-11-2016  0.56   NaN   NaN   NaN
# 21-05-2017   NaN  0.69   NaN   NaN
# 22-01-2017  0.31   NaN   NaN   NaN
# 23-10-2016  0.74   NaN   NaN   NaN
# 24-09-2016   NaN   NaN   NaN  1.66
# 25-02-2017   NaN  0.28   NaN   NaN
# 25-04-2017   NaN   NaN  1.33   NaN
# 26-11-2016   NaN  0.42   NaN   NaN
# 26-12-2016  0.65   NaN   NaN   NaN
# 27-08-2016  0.18   NaN   NaN   NaN
# 30-04-2017  0.68   NaN   NaN   NaN
# 30-10-2016  0.42   NaN   NaN   NaN
# 31-01-2017   NaN  1.20   NaN   NaN
# 31-12-2016   NaN   NaN  0.86   NaN

# %%
sns.heatmap(df01,cmap='coolwarm')

# %%
df011=df.pivot_table(index='FTLG',columns='Date',values='xGA')
df011
# Out:
# Date  01-04-2017  01-10-2016  03-12-2016  04-01-2017  04-02-2017  05-04-2017  \
# FTLG
# 0            NaN        0.27         NaN         NaN         NaN         NaN
# 1            NaN         NaN        2.24         NaN        0.95        2.26
# 2           1.57         NaN         NaN        1.01         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
#
# Date  05-11-2016  06-03-2017  08-04-2017  08-05-2017  ...  24-09-2016  \
# FTLG                                                  ...
# 0           0.01         NaN         NaN        0.07  ...         NaN
# 1            NaN        0.45        0.38         NaN  ...         NaN
# 2            NaN         NaN         NaN         NaN  ...         NaN
# 3            NaN         NaN         NaN         NaN  ...        1.66
#
# Date  25-02-2017  25-04-2017  26-11-2016  26-12-2016  27-08-2016  30-04-2017  \
# FTLG
# 0            NaN         NaN         NaN        0.65        0.18        0.68
# 1           0.28         NaN        0.42         NaN         NaN         NaN
# 2            NaN        1.33         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
#
# Date  30-10-2016  31-01-2017  31-12-2016
# FTLG
# 0           0.42         NaN         NaN
# 1            NaN         1.2         NaN
# 2            NaN         NaN        0.86
# 3            NaN         NaN         NaN
#
# [4 rows x 38 columns]

# %%
sns.heatmap(df011,cmap='coolwarm')

# %%
df_xG=df.xG
df_xGA=df.xGA
df_xG_Diff=df_xG-df_xGA

print((df_xG_Diff).to_string(index=False),"\n\n",(df.WDL).to_string(index=False))
# Out:
#  1.01
#  0.98
#  2.68
#  0.96
# -0.26
# -1.05
#  1.72
#  2.94
#  1.51
#  0.73
#  1.93
#  1.13
#  0.83
# -0.96
#  0.34
#  0.75
#  0.45
#  1.06
#  1.09
# -0.10
#  0.56
#  1.16
# -0.13
#  1.00
# -0.11
#  0.95
#  1.56
#  1.01
#  1.60
# -0.89
#  1.14
# -0.68
#  0.11
#  1.14
#  2.21
#  1.24
#  1.77
#  2.05
#
#   W
#  W
#  W
#  D
#  L
#  L
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  W
#  L
#  W
#  W
#  D
#  W
#  D
#  W
#  W
#  W
#  L
#  W
#  W
#  L
#  W
#  W
#  W
#  W
#  W
#  W

# %%
pos_count=0
neg_count =0
null_count=0
for i in df_xG_Diff:
    if i > 0: 
        pos_count += 1
    elif i < 0: 
        neg_count += 1
    else:
        null_count+=1
print("Positive xG in 38 matches: ",pos_count)
print("Negative xG in 38 matches: ",neg_count)
print("Null Difference in xG in 38 matches: ",null_count)
# Out:
# Positive xG in 38 matches:  30
# Negative xG in 38 matches:  8
# Null Difference in xG in 38 matches:  0

# %%
df_FTWG=df.FTWG
df_FTLG=df.FTLG
df_GD=df_FTWG-df_FTLG
print((df_GD).to_string(index=False),"\n\n\n",df.WDL)
# Out:
#  1
#  1
#  3
#  0
# -1
# -3
#  2
#  3
#  4
#  2
#  5
#  1
#  1
#  2
#  1
#  1
#  1
#  3
#  2
# -2
#  3
#  2
#  0
#  2
#  0
#  2
#  1
#  1
# -1
#  1
#  2
# -2
#  2
#  3
#  3
#  1
#  1
#  4
#
#
#  0     W
# 1     W
# 2     W
# 3     D
# 4     L
# 5     L
# 6     W
# 7     W
# 8     W
# 9     W
# 10    W
# 11    W
# 12    W
# 13    W
# 14    W
# 15    W
# 16    W
# 17    W
# 18    W
# 19    L
# 20    W
# 21    W
# 22    D
# 23    W
# 24    D
# 25    W
# 26    W
# 27    W
# 28    L
# 29    W
# 30    W
# 31    L
# 32    W
# 33    W
# 34    W
# 35    W
# 36    W
# 37    W
# Name: WDL, dtype: object

# %%
one_count=0
two_count=0
three_count=0
for i in df_GD:
    if i==1:
        one_count+=1
    elif i==2:
        two_count+=1
    elif i==3:
        three_count+=1
        
print("GD 1 : ",one_count)
print("GD 2 : ",two_count)
print("GD 3 : ",three_count)
# Out:
# GD 1 :  12
# GD 2 :  9
# GD 3 :  6

# %%
pos_count=0
neg_count =0
null_count=0
for i in df_GD:
    if i > 0: 
        pos_count += 1
    elif i < 0: 
        neg_count += 1
    else:
        null_count+=1
print("Positive GD in 38 matches i.e. Wins: ",pos_count)
print("Negative GD in 38 matches i.e. Loss: ",neg_count)
print("Null Difference in GD in 38 matches i.e. Draws: ",null_count)
# Out:
# Positive GD in 38 matches i.e. Wins:  30
# Negative GD in 38 matches i.e. Loss:  5
# Null Difference in GD in 38 matches i.e. Draws:  3

# %% [markdown]
# -ve PPDA means they pressed better and with intensity
#
# +ve PPDA means they pressed worse and with lesser intensity

# %%
df_PPDA=df.PPDA
df_aPPDA=df.aPPDA
df_PPDA_Diff=df_PPDA-df_aPPDA
print((df_PPDA_Diff).to_string(index=False),df.WDL)
# Out:
#  -5.63
#  -1.49
#   2.35
#  -3.51
#   4.62
#   0.38
#  -3.69
#  -1.58
#   2.61
#  -5.30
#  -0.31
#  -2.11
#   2.88
#   7.77
#  -4.83
#  -8.01
#   3.38
#   3.80
# -11.92
#   2.35
# -13.46
#   5.63
#   5.00
#  -1.06
# -10.74
#  -4.87
#   2.78
#  -6.92
#  -8.86
#   6.99
#   3.93
#  -1.57
#   5.49
#   6.67
#  12.04
#  -7.53
#   5.51
#  -2.45 0     W
# 1     W
# 2     W
# 3     D
# 4     L
# 5     L
# 6     W
# 7     W
# 8     W
# 9     W
# 10    W
# 11    W
# 12    W
# 13    W
# 14    W
# 15    W
# 16    W
# 17    W
# 18    W
# 19    L
# 20    W
# 21    W
# 22    D
# 23    W
# 24    D
# 25    W
# 26    W
# 27    W
# 28    L
# 29    W
# 30    W
# 31    L
# 32    W
# 33    W
# 34    W
# 35    W
# 36    W
# 37    W
# Name: WDL, dtype: object

# %%
pos_count=0
neg_count =0
null_count=0
for i in df_PPDA_Diff:
    if i > 0: 
        pos_count += 1
    elif i < 0: 
        neg_count += 1
    else:
        null_count+=1
print("Positive PPDA in 38 matches : ",pos_count)
print("Negative PPDA in 38 matches : ",neg_count)
print("Null Difference in PPDA in 38 matches : ",null_count)
# Out:
# Positive PPDA in 38 matches :  18
# Negative PPDA in 38 matches :  20
# Null Difference in PPDA in 38 matches :  0

# %%
df.WDL
# Out:
# 0     W
# 1     W
# 2     W
# 3     D
# 4     L
# 5     L
# 6     W
# 7     W
# 8     W
# 9     W
# 10    W
# 11    W
# 12    W
# 13    W
# 14    W
# 15    W
# 16    W
# 17    W
# 18    W
# 19    L
# 20    W
# 21    W
# 22    D
# 23    W
# 24    D
# 25    W
# 26    W
# 27    W
# 28    L
# 29    W
# 30    W
# 31    L
# 32    W
# 33    W
# 34    W
# 35    W
# 36    W
# 37    W
# Name: WDL, dtype: object

# %%
df.plot.line(x='Date',y='FTWG',lw=3,color='r',figsize=(12,3))

# %%
sns.lineplot(data=df.FTWG, color="r",lw=5)
ax2 = plt.twinx()
sns.lineplot(data=df.xG, color="b", ax=ax2,lw=1)

# %%
sns.lineplot(data=df.FTLG, color="r",lw=5)
ax2 = plt.twinx()
sns.lineplot(data=df.xGA, color="b", ax=ax2,lw=1)

# %%
labels=np.array(['FTWG','FTLG','xG','xGA'])
stats=df.loc[15,labels].values
angles=np.linspace(0, 2*np.pi, len(labels), endpoint=False)
# close the plot
stats=np.concatenate((stats,[stats[0]]))
angles=np.concatenate((angles,[angles[0]]))

# %%
fig=plt.figure()
ax = fig.add_subplot(111, polar=True)  
ax.plot(angles, stats, 'o-', linewidth=2)  
ax.fill(angles, stats, alpha=0.25) 
ax.set_thetagrids(angles * 180/np.pi, labels) 
ax.set_title([df.loc[15,"HomeTeam"]]) 
#ax.set_rlim(0,250)
ax.grid(True)

#For 36th Match of Leicester City

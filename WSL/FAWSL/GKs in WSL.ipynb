# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Karthik Garimella\Desktop\Data Analysis\GK WSL.csv',encoding='latin1')

# %%
df
# Out:
#     Index Attributes      Team              Player
# 0       2       GA90  1.800000     Karima Benameur
# 1       3      Save% -4.145631     Karima Benameur
# 2       5    PSxG+/- -4.800000     Karima Benameur
# 3       8       Stp% -0.411765     Karima Benameur
# 4       7    Launch% -3.875817     Karima Benameur
# 5       9    #OPA/90 -0.196507     Karima Benameur
# 6      11       GA90  0.610000   Ann-Katrin Berger
# 7      12      Save%  2.378641   Ann-Katrin Berger
# 8      14    PSxG+/-  2.500000   Ann-Katrin Berger
# 9      17       Stp%  5.000000   Ann-Katrin Berger
# 10     16    Launch% -1.091503   Ann-Katrin Berger
# 11     18    #OPA/90 -1.681223   Ann-Katrin Berger
# 12     20       GA90  1.000000          Mary Earps
# 13     21      Save%  0.145631          Mary Earps
# 14     23    PSxG+/- -3.900000          Mary Earps
# 15     26       Stp% -1.058824          Mary Earps
# 16     25    Launch% -2.594771          Mary Earps
# ...

# %%
sns.scatterplot(data=df, x="Attributes", y= 'Team',hue='Player')

# %%
from scipy.interpolate import make_interp_spline

ysmoothed = gaussian_filter1d(df.Team, sigma=2)

# %%
sns.set_theme(style="white",palette=None)
ax = sns.lineplot(x="Attributes", y='Team', data=df,hue='Player',linewidth = 3 , marker="o",markersize=14)
sns.set(rc={'figure.figsize':(15,15)})
ax.legend(markerscale=50)
ax.legend(prop={'size': 15},title='Player Colour',bbox_to_anchor=(1.25, 0.95))
plt.ylabel('')
plt.xlabel('Attributes',fontname="Times New Roman",fontsize=20)
plt.title('WSL Gks performace on certain metrics',fontsize=20, y=1.08)


plt.text(0.063,1.009, 'Goals Allowed/90', horizontalalignment='center',
     verticalalignment='center', transform=ax.transAxes)
plt.axvline(x=0.42058956)


plt.text(0.37,1.009, 'Saving % and Expected Gls - Gls and Stop %', horizontalalignment='center',
     verticalalignment='center', transform=ax.transAxes)
plt.axvline(x=3.52058956)



plt.text(0.77,1.009, 'Succesfull Passes beyond 40 Yards', horizontalalignment='center',
     verticalalignment='center', transform=ax.transAxes)
plt.axvline(x=4.52058956)


plt.text(0.95,1.009, 'Sweeping/90', horizontalalignment='center',
     verticalalignment='center', transform=ax.transAxes)



plt.text(1,-0.1,'Data : Statsbomb via FBREF',horizontalalignment='center',
     verticalalignment='center', transform=ax.transAxes)
# Out:
# Text(1, -0.1, 'Data : Statsbomb via FBREF')

# %%
sns.set_theme(style="white",palette=None)
ax = sns.lineplot(x="Attributes", y='Team', data=df,hue='Player')
sns.set(rc={'figure.figsize':(15,15)})
ax.legend(markerscale=50)
ax.legend(prop={'size': 20},)

# %%
sns.displot(data=df, x="Team", hue="Player", kind="kde")

# %%
df1 = pd.read_csv(r'C:\Users\Karthik Garimella\Desktop\Data Analysis\WSL GK Advanced.csv',encoding='latin1')

# %%
df1.head()
# Out:
#     Rk             Player   Nation Pos            Squad   Age    Born   90s  \
# 0  1.0   Mackenzie Arnold   au AUS  GK         West Ham  27.0  1994.0  18.0
# 1  2.0    Karima Benameur   fr FRA  GK  Manchester City  32.0  1989.0  10.0
# 2  3.0  Ann-Katrin Berger   de GER  GK          Chelsea  30.0  1990.0  13.2
# 3  4.0   Courtney Brosnan   ie IRL  GK          Everton  25.0  1995.0   4.0
# 4  5.0         Mary Earps  eng ENG  GK   Manchester Utd  28.0  1993.0  22.0
#
#      GA  PKA  ...  Att.2  Launch%.1  AvgLen.1    Opp   Stp  Stp%  #OPA  \
# 0  30.0  2.0  ...  173.0       58.4      40.5  166.0  19.0  11.4  26.0
# 1  18.0  2.0  ...   59.0       18.6      22.3   64.0   5.0   7.8  11.0
# 2   8.0  0.0  ...   86.0       37.2      33.2   88.0  15.0  17.0  10.0
# 3   7.0  0.0  ...   34.0       17.6      22.1   39.0   2.0   5.1   8.0
# 4  22.0  1.0  ...  158.0       49.4      38.3  165.0  11.0   6.7  18.0
#
#    #OPA/90  AvgDist  Matches
# 0     1.44     16.2  Matches
# ...

# %%
df1.drop([26], axis=0, inplace=True)

# %%
df1[['Player','#OPA/90','Squad']]
# Out:
#                   Player   #OPA/90               Squad
# 0       Mackenzie Arnold  1.288210            West Ham
# 1        Karima Benameur -0.196507     Manchester City
# 2      Ann-Katrin Berger -1.681223             Chelsea
# 3       Courtney Brosnan  3.733624             Everton
# 4             Mary Earps -1.419214      Manchester Utd
# 5         Hannah Hampton -3.209607     Aston Villa LFC
# 6          Sophie Harris -5.000000  Leicester City WFC
# 7         Marie Hourihan -1.899563     Birmingham City
# 8             Lucy Jones  1.331878     Birmingham City
# 9         Khiara Keating -0.720524     Manchester City
# 10  Tinja-Riikka Korpela -2.205240           Tottenham
# 11        Demi Lambourne  3.733624  Leicester City WFC
# 12             Anna Leat  1.550218            West Ham
# 13        Kirstie Levell  5.000000  Leicester City WFC
# 14         Sandy MacIver  1.288210             Everton
# 15         Grace Moloney -1.419214             Reading
# ...

# %%
df1['#OPA/90']=(df1['#OPA/90']-df1['#OPA/90'].min())/(df1['#OPA/90'].max()-df1['#OPA/90'].min())

# %%
df1['#OPA/90'] = (10 * df1['#OPA/90']) - 5

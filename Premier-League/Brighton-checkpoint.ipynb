# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme()

# %%
# %matplotlib inline

# %%
df1=pd.read_csv(r'C:\Users\Karthik Garimella\Desktop\Project\PL\Brighton.csv')

# %%
df2=pd.read_csv(r'C:\Users\Karthik Garimella\Desktop\Project\PL\Leeds.csv')

# %%
df1.head()
# Out:
#              Player   Nation    Pos     Age    MP  Starts    Min   90s  Gls  \
# 0         Ben White  eng ENG  DF,MF  23-204  31.0    31.0  2,741  30.5  0.0
# 1        Lewis Dunk  eng ENG     DF  29-160  30.0    30.0  2,699  30.0  4.0
# 2     Yves Bissouma   ml MLI     MF  24-243  31.0    30.0  2,662  29.6  1.0
# 3       Neal Maupay   fr FRA  FW,MF  24-259  31.0    27.0  2,333  25.9  8.0
# 4  Leandro Trossard   be BEL  FW,MF  26-147  30.0    26.0  2,281  25.3  4.0
#
#    Ast  ...    xG  npxG   xA  npxG+xA  xG/90  xA/90  xG+xA/90  npxG/90  \
# 0  0.0  ...   0.5   0.5  0.7      1.2   0.02   0.02      0.04     0.02
# 1  0.0  ...   2.4   2.4  0.6      3.0   0.08   0.02      0.10     0.08
# 2  0.0  ...   1.0   1.0  1.0      2.0   0.03   0.03      0.07     0.03
# 3  2.0  ...  12.5   9.4  3.4     12.9   0.48   0.13      0.61     0.36
# 4  5.0  ...   4.3   4.3  3.9      8.2   0.17   0.15      0.32     0.17
#
#    npxG+xA/90  Matches
# 0        0.04  Matches
# 1        0.10  Matches
# ...

# %%
count1=0
for i in df1.Gls:
    count1=count1+i
count1
# Out:
# nan

# %%
with open("Brighton.csv") as fin:
    fin.next()
    total = sum(int(r[8]) for r in csv.reader(fin)
# Out:
#   File "<ipython-input-10-16ea46e5739c>", line 3
#     total = sum(int(r[8]) for r in csv.reader(fin)
#                                                   ^
# SyntaxError: unexpected EOF while parsing

# %%
with open("Brighton.csv") as fin:
    headerline = fin.next()
    total = 0
    for row in csv.reader(fin):
        total += int(row[8])
print(" total")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-e1ed071cdda3> in <module>
#       1 with open("Brighton.csv") as fin:
# ----> 2     headerline = fin.next()
#       3     total = 0
#       4     for row in csv.reader(fin):
#       5         total += int(row[8])
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'next'

# %%
import csv

with open("Brighton.csv") as csv_file:
    reader = csv.DictReader(csv_file)
    total = sum(float(row["MP"]) for row in reader)
print(total)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-38eeff4f0b1a> in <module>
#       3 with open("Brighton.csv") as csv_file:
#       4     reader = csv.DictReader(csv_file)
# ----> 5     total = sum(float(row["MP"]) for row in reader)
#       6 print(total)
#
# <ipython-input-16-38eeff4f0b1a> in <genexpr>(.0)
#       3 with open("Brighton.csv") as csv_file:
#       4     reader = csv.DictReader(csv_file)
# ----> 5     total = sum(float(row["MP"]) for row in reader)
#       6 print(total)
#
# ValueError: could not convert string to float:

# %%
df1.plot(x="Player", y=["xG+xA/90"], kind="barh",figsize=(5,15))

# %%
df1.plot(x="Player", y=["xG/90"], kind="barh",figsize=(10,15))

# %%
df1.plot(x="Player", y=["xA/90"], kind="barh",figsize=(10,15))

# %%
df1.plot(x="Player", y=["Ast","xA"], kind="barh",figsize=(15,15))

# %%
df1.plot(x="Player", y=["Gls", "xG"], kind="bar",figsize=(15,5))

# %%
df1.plot(x="Player", y=["Gls", "xG"], kind="barh",figsize=(10,15))

# %%
df2.plot(x="Player", y=["Gls", "xG"], kind="bar",figsize=(15,5))

# %%
ax = df.plot.scatter(x="Player", y="Gls", color="DarkBlue", label="Group 1")

df.plot.scatter(x="Player", y="xG", color="DarkGreen", label="Group 2", ax=ax);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-efd8509c75cd> in <module>
# ----> 1 ax = df.plot.scatter(x="Player", y="Gls", color="DarkBlue", label="Group 1")
#       2
#       3 df.plot.scatter(x="Player", y="xG", color="DarkGreen", label="Group 2", ax=ax);
#
# E:\Ananconda1\lib\site-packages\pandas\plotting\_core.py in scatter(self, x, y, s, c, **kwargs)
#    1442             ...                       colormap='viridis')
#    1443         """
# -> 1444         return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#    1445
#    1446     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None, **kwargs):
#
# E:\Ananconda1\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     736         if kind in self._dataframe_kinds:
#     737             if isinstance(data, ABCDataFrame):
# ...

# %%
df3=pd.read_csv(r'C:\Users\Karthik Garimella\Desktop\Project\PL\Timing Chat Brighton.csv')

# %%
sns.lmplot(x="G", y="Sh", hue="Timing", data=df3)

# %%
df3.plot(x="Timing", y=["G", "xG"], kind="bar",figsize=(15,5))

# %%
g=sns.jointplot(x='Gls',y='xG',data=df3,kind='reg',scatter_kws={'s':10})
for i,row in df.iterrows(): # loop through rows of the df
    plt.text(row.Gls + 0.9, row.xG + 0.9, row.Timing)  # xloc of text, yloc of text, text
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-24a91803f8c8> in <module>
# ----> 1 g=sns.jointplot(x='Gls',y='xG',data=df3,kind='reg',scatter_kws={'s':10})
#       2 for i,row in df.iterrows(): # loop through rows of the df
#       3     plt.text(row.Gls + 0.9, row.xG + 0.9, row.Timing)  # xloc of text, yloc of text, text
#
# E:\Ananconda1\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# E:\Ananconda1\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
# ...

# %%
sns.relplot(x="Gls", y="xG", hue="Player",
            sizes=(40, 40), alpha=1,
            height=6, data=df1,s=500)

# %%
sns.jointplot(x='Gls',y='xG',data=df1,kind='reg',scatter_kws={'s':50})

# %%
g=sns.jointplot(x='Gls',y='xG',data=df1,kind='reg',scatter_kws={'s':10})
for i,row in df.iterrows(): # loop through rows of the df
    plt.text(row.Gls + 0.9, row.xG + 0.1, row.Player)  # xloc of text, yloc of text, text
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
